# %% [markdown]
# # Fully-Connected Neural Networks and Dropout

# %%
student_id =  99105901
student_name = 'Amirhossein Akbari'

print("your student id:", student_id)
print("your name:", student_name)
# Out:
# your student id: 99105901
# your name: Amirhossein Akbari

# %% [markdown]
# ## Setup Code
# First, run this cell load the autoreload extension. This allows us to edit .py source files, and re-import them into the notebook for a seamless editing and debugging experience.

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Google Colab Setup
# Next we need to run a few commands to set up our environment on Google Colab. If you are running this notebook on a local machine you can skip this section.
#
# Run the following cell to mount your Google Drive. Follow the link, sign in to your Google account (the same account you used to store this notebook!).

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# import os

# # TODO: Fill in the Google Drive path where you uploaded the assignment
# # Example: If you create a deepHW2 folder and put all the files under Q1 folder, then 'deepHW2/Q1'
# GOOGLE_DRIVE_PATH_AFTER_MYDRIVE = None
# GOOGLE_DRIVE_PATH = os.path.join('drive', 'My Drive', GOOGLE_DRIVE_PATH_AFTER_MYDRIVE)
# print(os.listdir(GOOGLE_DRIVE_PATH))

# %% [markdown]
# Once you have successfully mounted your Google Drive and located the path to this assignment, run th following cell to allow us to import from the `.py` files of this assignment.

# %%
# import sys
# sys.path.append(GOOGLE_DRIVE_PATH)

# import time, os
# os.environ["TZ"] = "US/Eastern"
# time.tzset()

# fully_connected_networks_path = os.path.join(GOOGLE_DRIVE_PATH, 'fully_connected_networks.py')
# fully_connected_networks_edit_time = time.ctime(os.path.getmtime(fully_connected_networks_path))
# print('fully_connected_networks.py last edited on %s' % fully_connected_networks_edit_time)

# %% [markdown]
# # Data preprocessing

# %% [markdown]
# ## Setup code
# Run some setup code for this notebook: Import some useful packages and increase the default figure size.

# %%
import libs
import torch
import torchvision
import matplotlib.pyplot as plt
import statistics
import random
import time
import math
# %matplotlib inline

from libs import reset_seed, Solver

plt.rcParams['figure.figsize'] = (10.0, 8.0)
plt.rcParams['font.size'] = 16

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")
# Out:
# Using cuda device

# %% [markdown]
# ## Load the CIFAR-10 dataset
# Then, we will first load the CIFAR-10 dataset. The utility function `libs.data.preprocess_cifar10()` returns the entire CIFAR-10 dataset as a set of six **Torch tensors** while also preprocessing the RGB images:
#
# - `X_train` contains all training images (real numbers in the range $[0, 1]$)
# - `y_train` contains all training labels (integers in the range $[0, 9]$)
# - `X_val` contains all validation images
# - `y_val` contains all validation labels
# - `X_test` contains all test images
# - `y_test` contains all test labels

# %%
import libs

reset_seed(0)
# If you are using gpu, you can set cuda to true
data_dict = libs.data.preprocess_cifar10(cuda=False, dtype=torch.float64)
for i in data_dict:
    data_dict[i] = data_dict[i].to(device)
print('Train data shape: ', data_dict['X_train'].shape)
print('Train labels shape: ', data_dict['y_train'].shape)
print('Validation data shape: ', data_dict['X_val'].shape)
print('Validation labels shape: ', data_dict['y_val'].shape)
print('Test data shape: ', data_dict['X_test'].shape)
print('Test labels shape: ', data_dict['y_test'].shape)
# Out:
# Train data shape:  torch.Size([40000, 3072])
# Train labels shape:  torch.Size([40000])
# Validation data shape:  torch.Size([10000, 3072])
# Validation labels shape:  torch.Size([10000])
# Test data shape:  torch.Size([10000, 3072])
# Test labels shape:  torch.Size([10000])

# %% [markdown]
# # Fully-connected neural networks

# %% [markdown]
# In this exercise we will implement fully-connected networks using a more modular approach. For each layer we will implement a `forward` and a `backward` function. The `forward` function will receive inputs, weights, and other parameters and will return both an output and a `cache` object storing data needed for the backward pass, like this:
#
# ```python
# def forward(x, w):
#   """ Receive inputs x and weights w """
#   # Do some computations ...
#   z = # ... some intermediate value
#   # Do some more computations ...
#   out = # the output
#
#   cache = (x, w, z, out) # Values we need to compute gradients
#
#   return out, cache
# ```
#
# The backward pass will receive upstream derivatives and the `cache` object, and will return gradients with respect to the inputs and weights, like this:
#
# ```python
# def backward(dout, cache):
#   """
#   Receive dout (derivative of loss with respect to outputs) and cache,
#   and compute derivative with respect to inputs.
#   """
#   # Unpack cache values
#   x, w, z, out = cache
#
#   # Use values in cache to compute derivatives
#   dx = # Derivative of loss with respect to x
#   dw = # Derivative of loss with respect to w
#
#   return dx, dw
# ```
#
# After implementing a bunch of layers this way, we will be able to easily combine them to build classifiers with different architectures.
#
# In addition to implementing fully-connected networks of arbitrary depth, we will also explore different update rules for optimization, and introduce Dropout as a regularizer as a tool to more efficiently optimize deep networks.

# %% [markdown]
# # Linear layer
#
# For each layer we implement, we will define a class with two static methods `forward` and `backward`. The class structure is currently provided in `fully_connected_layers.py`, you will be implementing both the `forward` and `backward` methods.

# %% [markdown]
# ## Linear layer: forward
# Implement the `Linear.forward` function in `fully_connected_layers.py`. Once you are done you can test your implementaion by running the next cell. You should see errors less than `1e-7`.

# %%
from fully_connected_networks import Linear

# Test the Linear.forward function
num_inputs = 2
input_shape = torch.tensor((4, 5, 6))
output_dim = 3

input_size = num_inputs * torch.prod(input_shape)
weight_size = output_dim * torch.prod(input_shape)

x = torch.linspace(-0.1, 0.5, steps=input_size, dtype=torch.float64, device=device)
w = torch.linspace(-0.2, 0.3, steps=weight_size, dtype=torch.float64, device=device)
b = torch.linspace(-0.3, 0.1, steps=output_dim, dtype=torch.float64, device=device)
x = x.reshape(num_inputs, *input_shape)
w = w.reshape(torch.prod(input_shape), output_dim)

out, _ = Linear.forward(x, w, b)
correct_out = torch.tensor([[1.49834984, 1.70660150, 1.91485316],
                            [3.25553226, 3.51413301, 3.77273372]]
                            ).double().to(device)

print('Testing Linear.forward function:')
print('difference: ', libs.grad.rel_error(out, correct_out))
# Out:
# Testing Linear.forward function:
# difference:  3.6830429120909964e-08

# %% [markdown]
# ## Linear layer: backward
# Now implement the `Linear.backward` function and test your implementation using numeric gradient checking.
#
# Run the following to test your implementation of `Linear.backward`. You should see errors less than `1e-7`.

# %%
from fully_connected_networks import Linear

# Test the Linear.backward function
reset_seed(0)
x = torch.randn(10, 2, 3, dtype=torch.float64, device=device)
w = torch.randn(6, 5, dtype=torch.float64, device=device)
b = torch.randn(5, dtype=torch.float64, device=device)
dout = torch.randn(10, 5, dtype=torch.float64, device=device)

dx_num = libs.grad.compute_numeric_gradient(lambda x: Linear.forward(x, w, b)[0], x, dout)
dw_num = libs.grad.compute_numeric_gradient(lambda w: Linear.forward(x, w, b)[0], w, dout)
db_num = libs.grad.compute_numeric_gradient(lambda b: Linear.forward(x, w, b)[0], b, dout)

_, cache = Linear.forward(x, w, b)
dx, dw, db = Linear.backward(dout, cache)

# The error should be around e-10 or less
print('Testing Linear.backward function:')
print('dx error: ', libs.grad.rel_error(dx_num, dx))
print('dw error: ', libs.grad.rel_error(dw_num, dw))
print('db error: ', libs.grad.rel_error(db_num, db))
# Out:
# Testing Linear.backward function:
# dx error:  5.170864758949246e-10
# dw error:  3.293741405059995e-10
# db error:  5.373171200544344e-10

# %% [markdown]
# # ReLU activation
#
# We will now implement the ReLU nonlinearity. As above, we will define a class with two empty static methods, and implement them in upcoming cells. The class structure can be found in `fully_connected_networks.py`

# %% [markdown]
# ## ReLU activation: forward
# Implement the forward pass for the ReLU activation function in the `ReLU.forward` function. You **should not** change the input tensor with an in-place operation.
#
# Run the following to test your implementation of the ReLU forward pass. Your errors should be less than `1e-7`.

# %%
from fully_connected_networks import ReLU

reset_seed(0)
x = torch.linspace(-0.5, 0.5, steps=12, dtype=torch.float64, device=device)
x = x.reshape(3, 4)

out, _ = ReLU.forward(x)
correct_out = torch.tensor([[ 0.,          0.,          0.,          0.,        ],
                            [ 0.,          0.,          0.04545455,  0.13636364,],
                            [ 0.22727273,  0.31818182,  0.40909091,  0.5,       ]],
                            dtype=torch.float64,
                            device=device)

# Compare your output with ours. The error should be on the order of e-9
print('Testing ReLU.forward function:')
print('difference: ', libs.grad.rel_error(out, correct_out))
# Out:
# Testing ReLU.forward function:
# difference:  4.5454545613554664e-09

# %% [markdown]
# ## ReLU activation: backward
# Now implement the backward pass for the ReLU activation function.
#
# Again, you should not change the input tensor with an in-place operation.
#
# Run the following to test your implementation of `ReLU.backward`. Your errors should be less than `1e-8`.

# %%
from fully_connected_networks import ReLU

reset_seed(0)
x = torch.randn(10, 10, dtype=torch.float64, device=device)
dout = torch.randn(*x.shape, dtype=torch.float64, device=device)

dx_num = libs.grad.compute_numeric_gradient(lambda x: ReLU.forward(x)[0], x, dout)

_, cache = ReLU.forward(x)
dx = ReLU.backward(dout, cache)

# The error should be on the order of e-10
print('Testing ReLU.backward function:')
print('dx error: ', libs.grad.rel_error(dx_num, dx))
# Out:
# Testing ReLU.backward function:
# dx error:  2.6317796097761553e-10

# %% [markdown]
# # "Sandwich" layers
# There are some common patterns of layers that are frequently used in neural nets. For example, linear layers are frequently followed by a ReLU nonlinearity. To make these common patterns easy, we define a convenience layer.
#
# This also shows how our layer abstraction allows us to implement new layers by composing existing layer implementations. This is a powerful mechanism for structuring deep learning code in a modular fashion.
#
# For now take a look at the `forward` and `backward` functions in `Linear_ReLU`, and run the following to numerically gradient check the backward pass.
#
# Run the following to test the implementation of the `Linear_ReLU` layer using numeric gradient checking. You should see errors less than `1e-8`

# %%
from fully_connected_networks import Linear_ReLU

reset_seed(0)
x = torch.randn(2, 3, 4, dtype=torch.float64, device=device)
w = torch.randn(12, 10, dtype=torch.float64, device=device)
b = torch.randn(10, dtype=torch.float64, device=device)
dout = torch.randn(2, 10, dtype=torch.float64, device=device)

out, cache = Linear_ReLU.forward(x, w, b)
dx, dw, db = Linear_ReLU.backward(dout, cache)

dx_num = libs.grad.compute_numeric_gradient(lambda x: Linear_ReLU.forward(x, w, b)[0], x, dout)
dw_num = libs.grad.compute_numeric_gradient(lambda w: Linear_ReLU.forward(x, w, b)[0], w, dout)
db_num = libs.grad.compute_numeric_gradient(lambda b: Linear_ReLU.forward(x, w, b)[0], b, dout)

# Relative error should be around e-8 or less
print('Testing Linear_ReLU.forward and Linear_ReLU.backward:')
print('dx error: ', libs.grad.rel_error(dx_num, dx))
print('dw error: ', libs.grad.rel_error(dw_num, dw))
print('db error: ', libs.grad.rel_error(db_num, db))
# Out:
# Testing Linear_ReLU.forward and Linear_ReLU.backward:
# dx error:  1.4564739946431168e-09
# dw error:  6.424556508465271e-10
# db error:  8.915028842081707e-10

# %% [markdown]
# # Loss layers: Softmax
# We will now implement the Softmax. As above, we will define a function and you can be found in `fully_connected_networks.py`
#
#
# Run the following to perform numeric gradient checking on the loss function. You should see error less than `1e-6` for softmax_loss.

# %%
from fully_connected_networks import softmax_loss

reset_seed(0)
num_classes, num_inputs = 10, 50
x = 0.001 * torch.randn(num_inputs, num_classes, dtype=torch.float64, device=device)
y = torch.randint(num_classes, size=(num_inputs,), dtype=torch.int64, device=device)

dx_num = libs.grad.compute_numeric_gradient(lambda x: softmax_loss(x, y)[0], x)
loss, dx = softmax_loss(x, y)

# Test softmax_loss function. Loss should be close to 2.3 and dx error should be around e-8
print('\nTesting softmax_loss:')
print('loss: ', loss.item())
print('dx error: ', libs.grad.rel_error(dx_num, dx))
# Out:
# Testing softmax_loss:
# loss:  2.3026286102347924
# dx error:  9.02834960445298e-08

# %% [markdown]
# # Two-layer network
#
# Complete the implementation of the `TwoLayerNet` class. This class will serve as a model for the other networks you will implement in this assignment, so read through it to make sure you understand the API.
#
# Once you have finished implementing the forward and backward passes of your two-layer net, run the following to test your implementation:

# %%
from fully_connected_networks import TwoLayerNet, softmax_loss

reset_seed(0)
N, D, H, C = 3, 5, 50, 7
X = torch.randn(N, D, dtype=torch.float64, device=device)
y = torch.randint(C, size=(N,), dtype=torch.int64, device=device)

std = 1e-3
model = TwoLayerNet(
          input_dim=D,
          hidden_dim=H,
          num_classes=C,
          weight_scale=std,
          dtype=torch.float64,
          device=device
        )

print('Testing initialization ... ')
W1_std = torch.abs(model.params['W1'].std() - std)
b1 = model.params['b1']
W2_std = torch.abs(model.params['W2'].std() - std)
b2 = model.params['b2']
assert W1_std < std / 10, 'First layer weights do not seem right'
assert torch.all(b1 == 0), 'First layer biases do not seem right'
assert W2_std < std / 10, 'Second layer weights do not seem right'
assert torch.all(b2 == 0), 'Second layer biases do not seem right'

print('Testing test-time forward pass ... ')
model.params['W1'] = torch.linspace(-0.7, 0.3, steps=D * H, dtype=torch.float64, device=device).reshape(D, H)
model.params['b1'] = torch.linspace(-0.1, 0.9, steps=H, dtype=torch.float64, device=device)
model.params['W2'] = torch.linspace(-0.3, 0.4, steps=H * C, dtype=torch.float64, device=device).reshape(H, C)
model.params['b2'] = torch.linspace(-0.9, 0.1, steps=C, dtype=torch.float64, device=device)
X = torch.linspace(-5.5, 4.5, steps=N * D, dtype=torch.float64, device=device).reshape(D, N).t()
scores = model.loss(X)
correct_scores = torch.tensor(
  [[11.53165108,  12.2917344,   13.05181771,  13.81190102,  14.57198434, 15.33206765,  16.09215096],
   [12.05769098,  12.74614105,  13.43459113,  14.1230412,   14.81149128, 15.49994135,  16.18839143],
   [12.58373087,  13.20054771,  13.81736455,  14.43418138,  15.05099822, 15.66781506,  16.2846319 ]],
    dtype=torch.float64, device=device)
scores_diff = torch.abs(scores - correct_scores).sum()
assert scores_diff < 1e-6, 'Problem with test-time forward pass'

print('Testing training loss (no regularization)')
y = torch.tensor([0, 5, 1])
loss, grads = model.loss(X, y)
correct_loss = 3.4702243556
assert abs(loss - correct_loss) < 1e-10, 'Problem with training-time loss'

model.reg = 1.0
loss, grads = model.loss(X, y)
correct_loss = 49.719461034881775
assert abs(loss - correct_loss) < 1e-10, 'Problem with regularization loss'

# Errors should be around e-6 or less
for reg in [0.0, 0.7]:
  print('Running numeric gradient check with reg = ', reg)
  model.reg = reg
  loss, grads = model.loss(X, y)

  for name in sorted(grads):
    f = lambda _: model.loss(X, y)[0]
    grad_num = libs.grad.compute_numeric_gradient(f, model.params[name])
    print('%s relative error: %.2e' % (name, libs.grad.rel_error(grad_num, grads[name])))
# Out:
# Testing initialization ...
# Testing test-time forward pass ...
# Testing training loss (no regularization)
# Running numeric gradient check with reg =  0.0
# W1 relative error: 2.28e-07
# W2 relative error: 1.49e-09
# b1 relative error: 9.91e-07
# b2 relative error: 4.99e-09
# Running numeric gradient check with reg =  0.7
# W1 relative error: 3.20e-01
# W2 relative error: 4.43e-02
# b1 relative error: 6.27e-07
# b2 relative error: 2.72e-08

# %% [markdown]
# # Solver
#
# for this assignment we have split the logic for training models into a separate class. Read through `help(Solver)` to familiarize yourself with the API. After doing so, use a `Solver` instance to train a `TwoLayerNet` that achieves at least `50%` accuracy on the validation set.

# %%
print(help(Solver))
# Out:
# Help on class Solver in module libs.solver:
#
# class Solver(builtins.object)
#  |  Solver(model, data, **kwargs)
#  |
#  |  A Solver encapsulates all the logic necessary for training classification
#  |  models. The Solver performs stochastic gradient descent using different
#  |  update rules.
#  |  The solver accepts both training and validation data and labels so it can
#  |  periodically check classification accuracy on both training and validation
#  |  data to watch out for overfitting.
#  |  To train a model, you will first construct a Solver instance, passing the
#  |  model, dataset, and various options (learning rate, batch size, etc) to the
#  |  constructor. You will then call the train() method to run the optimization
#  |  procedure and train the model.
#  |  After the train() method returns, model.params will contain the parameters
#  |  that performed best on the validation set over the course of training.
#  |  In addition, the instance variable solver.loss_history will contain a list
#  |  of all losses encountered during training and the instance variables
#  |  solver.train_acc_history and solver.val_acc_history will be lists of the
#  |  accuracies of the model on the training and validation set at each epoch.
#  |  Example usage might look something like this:
#  |  data = {
#  |    'X_train': # training data
#  |    'y_train': # training labels
#  |    'X_val': # validation data
#  |    'y_val': # validation labels
#  |  }
#  |  model = MyAwesomeModel(hidden_size=100, reg=10)
#  |  solver = Solver(model, data,
#  |          update_rule=sgd,
#  |          optim_config={
#  |            'learning_rate': 1e-3,
#  |          },
#  |          lr_decay=0.95,
#  |          num_epochs=10, batch_size=100,
#  |          print_every=100,
#  |          device='cuda')
#  |  solver.train()
#  |  A Solver works on a model object that must conform to the following API:
#  |  - model.params must be a dictionary mapping string parameter names to torch
#  |    tensors containing parameter values.
#  |  - model.loss(X, y) must be a function that computes training-time loss and
#  |    gradients, and test-time classification scores, with the following inputs
#  |    and outputs:
#  |    Inputs:
#  |    - X: Array giving a minibatch of input data of shape (N, d_1, ..., d_k)
#  |    - y: Array of labels, of shape (N,) giving labels for X where y[i] is the
#  |    label for X[i].
#  |    Returns:
#  |    If y is None, run a test-time forward pass and return:
#  |    - scores: Array of shape (N, C) giving classification scores for X where
#  |    scores[i, c] gives the score of class c for X[i].
#  |    If y is not None, run a training time forward and backward pass and
#  |    return a tuple of:
#  |    - loss: Scalar giving the loss
#  |    - grads: Dictionary with the same keys as self.params mapping parameter
#  |    names to gradients of the loss with respect to those parameters.
#  |    - device: device to use for computation. 'cpu' or 'cuda'
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, model, data, **kwargs)
#  |      Construct a new Solver instance.
#  |      Required arguments:
#  |      - model: A model object conforming to the API described above
#  |      - data: A dictionary of training and validation data containing:
#  |        'X_train': Array, shape (N_train, d_1, ..., d_k) of training images
#  |        'X_val': Array, shape (N_val, d_1, ..., d_k) of validation images
#  |        'y_train': Array, shape (N_train,) of labels for training images
#  |        'y_val': Array, shape (N_val,) of labels for validation images
#  |      Optional arguments:
#  |      - update_rule: A function of an update rule. Default is sgd.
#  |      - optim_config: A dictionary containing hyperparameters that will be
#  |        passed to the chosen update rule. Each update rule requires different
#  |        hyperparameters but all update rules require a
#  |        'learning_rate' parameter so that should always be present.
#  |      - lr_decay: A scalar for learning rate decay; after each epoch the
#  |        learning rate is multiplied by this value.
#  |      - batch_size: Size of minibatches used to compute loss and gradient
#  |        during training.
#  |      - num_epochs: The number of epochs to run for during training.
#  |      - print_every: Integer; training losses will be printed every
#  |        print_every iterations.
#  |      - print_acc_every: We will print the accuracy every
#  |        print_acc_every epochs.
#  |      - verbose: Boolean; if set to false then no output will be printed
#  |        during training.
#  |      - num_train_samples: Number of training samples used to check training
#  |        accuracy; default is 1000; set to None to use entire training set.
#  |      - num_val_samples: Number of validation samples to use to check val
#  |        accuracy; default is None, which uses the entire validation set.
#  |      - checkpoint_name: If not None, then save model checkpoints here every
#  |        epoch.
#  |
#  |  check_accuracy(self, X, y, num_samples=None, batch_size=100)
#  |      Check accuracy of the model on the provided data.
#  |      Inputs:
#  |      - X: Array of data, of shape (N, d_1, ..., d_k)
#  |      - y: Array of labels, of shape (N,)
#  |      - num_samples: If not None, subsample the data and only test the model
#  |        on num_samples datapoints.
#  |      - batch_size: Split X and y into batches of this size to avoid using
#  |        too much memory.
#  |      Returns:
#  |      - acc: Scalar giving the fraction of instances that were correctly
#  |        classified by the model.
#  |
#  |  train(self, time_limit=None, return_best_params=True)
#  |      Run optimization to train the model.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  sgd(w, dw, config=None)
#  |      Performs vanilla stochastic gradient descent.
#  |      config format:
#  |      - learning_rate: Scalar learning rate.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#
# None

# %% [markdown]
# Use the Solver classe to create a solver instance that trains a TwoLayerNet to achieve at least 50% performance on the validation set.
#
# **Implement** `create_solver_instance` in `fully_connected_networks.py` to return a solver instance. Make sure to initialize the Solver instance with the input device.

# %%
from fully_connected_networks import create_solver_instance

reset_seed(0)
# Create a solver instance that achieves 50% performance on the validation set
solver = create_solver_instance(data_dict=data_dict, dtype=torch.float64, device=device)

solver.train()
# Out:
# (Time 0.04 sec; Iteration 1 / 16000) loss: 2.302568
# (Epoch 0 / 20) train acc: 0.112000; val_acc: 0.099900
# (Time 0.47 sec; Iteration 11 / 16000) loss: 2.303051
# (Time 0.51 sec; Iteration 21 / 16000) loss: 2.301004
# (Time 0.54 sec; Iteration 31 / 16000) loss: 2.304389
# (Time 0.58 sec; Iteration 41 / 16000) loss: 2.303142
# (Time 0.61 sec; Iteration 51 / 16000) loss: 2.301512
# (Time 0.65 sec; Iteration 61 / 16000) loss: 2.301890
# (Time 0.69 sec; Iteration 71 / 16000) loss: 2.302242
# (Time 0.72 sec; Iteration 81 / 16000) loss: 2.298258
# (Time 0.75 sec; Iteration 91 / 16000) loss: 2.302848
# (Time 0.79 sec; Iteration 101 / 16000) loss: 2.300921
# (Time 0.82 sec; Iteration 111 / 16000) loss: 2.299791
# (Time 0.86 sec; Iteration 121 / 16000) loss: 2.300470
# (Time 0.90 sec; Iteration 131 / 16000) loss: 2.300037
# (Time 0.93 sec; Iteration 141 / 16000) loss: 2.293944
# (Time 0.97 sec; Iteration 151 / 16000) loss: 2.294328
# (Time 1.00 sec; Iteration 161 / 16000) loss: 2.284662
# (Time 1.04 sec; Iteration 171 / 16000) loss: 2.290915
# (Time 1.07 sec; Iteration 181 / 16000) loss: 2.271511
# (Time 1.11 sec; Iteration 191 / 16000) loss: 2.283615
# (Time 1.14 sec; Iteration 201 / 16000) loss: 2.263977
# (Time 1.18 sec; Iteration 211 / 16000) loss: 2.256361
# (Time 1.22 sec; Iteration 221 / 16000) loss: 2.264970
# (Time 1.25 sec; Iteration 231 / 16000) loss: 2.258557
# (Time 1.29 sec; Iteration 241 / 16000) loss: 2.223372
# (Time 1.32 sec; Iteration 251 / 16000) loss: 2.255903
# (Time 1.36 sec; Iteration 261 / 16000) loss: 2.233637
# (Time 1.39 sec; Iteration 271 / 16000) loss: 2.196576
# (Time 1.43 sec; Iteration 281 / 16000) loss: 2.237885
# (Time 1.46 sec; Iteration 291 / 16000) loss: 2.141295
# (Time 1.49 sec; Iteration 301 / 16000) loss: 2.167705
# (Time 1.53 sec; Iteration 311 / 16000) loss: 2.193124
# (Time 1.56 sec; Iteration 321 / 16000) loss: 2.094430
# (Time 1.60 sec; Iteration 331 / 16000) loss: 2.143834
# (Time 1.64 sec; Iteration 341 / 16000) loss: 2.112405
# (Time 1.68 sec; Iteration 351 / 16000) loss: 2.168374
# (Time 1.72 sec; Iteration 361 / 16000) loss: 2.084081
# (Time 1.76 sec; Iteration 371 / 16000) loss: 2.104304
# (Time 1.79 sec; Iteration 381 / 16000) loss: 1.998641
# (Time 1.83 sec; Iteration 391 / 16000) loss: 2.091343
# (Time 1.87 sec; Iteration 401 / 16000) loss: 2.189034
# (Time 1.90 sec; Iteration 411 / 16000) loss: 2.100683
# (Time 1.94 sec; Iteration 421 / 16000) loss: 2.063132
# (Time 1.98 sec; Iteration 431 / 16000) loss: 2.064832
# (Time 2.02 sec; Iteration 441 / 16000) loss: 2.119197
# (Time 2.05 sec; Iteration 451 / 16000) loss: 2.032837
# (Time 2.09 sec; Iteration 461 / 16000) loss: 1.980606
# (Time 2.13 sec; Iteration 471 / 16000) loss: 2.063266
# (Time 2.16 sec; Iteration 481 / 16000) loss: 1.972105
# (Time 2.20 sec; Iteration 491 / 16000) loss: 2.116980
# (Time 2.23 sec; Iteration 501 / 16000) loss: 2.129170
# (Time 2.27 sec; Iteration 511 / 16000) loss: 1.970939
# (Time 2.30 sec; Iteration 521 / 16000) loss: 2.001406
# (Time 2.34 sec; Iteration 531 / 16000) loss: 1.826301
# (Time 2.37 sec; Iteration 541 / 16000) loss: 2.079902
# (Time 2.41 sec; Iteration 551 / 16000) loss: 1.928473
# (Time 2.45 sec; Iteration 561 / 16000) loss: 2.055791
# (Time 2.48 sec; Iteration 571 / 16000) loss: 2.122574
# (Time 2.52 sec; Iteration 581 / 16000) loss: 2.088016
# (Time 2.56 sec; Iteration 591 / 16000) loss: 1.945645
# (Time 2.59 sec; Iteration 601 / 16000) loss: 1.926849
# (Time 2.63 sec; Iteration 611 / 16000) loss: 2.006695
# (Time 2.66 sec; Iteration 621 / 16000) loss: 1.980830
# (Time 2.70 sec; Iteration 631 / 16000) loss: 1.895849
# (Time 2.73 sec; Iteration 641 / 16000) loss: 1.867926
# (Time 2.77 sec; Iteration 651 / 16000) loss: 2.101776
# (Time 2.81 sec; Iteration 661 / 16000) loss: 1.973396
# (Time 2.84 sec; Iteration 671 / 16000) loss: 1.900745
# (Time 2.88 sec; Iteration 681 / 16000) loss: 1.972930
# (Time 2.91 sec; Iteration 691 / 16000) loss: 1.993003
# (Time 2.95 sec; Iteration 701 / 16000) loss: 1.971344
# (Time 2.99 sec; Iteration 711 / 16000) loss: 2.064306
# (Time 3.02 sec; Iteration 721 / 16000) loss: 1.855056
# (Time 3.06 sec; Iteration 731 / 16000) loss: 2.020539
# (Time 3.10 sec; Iteration 741 / 16000) loss: 1.825711
# (Time 3.13 sec; Iteration 751 / 16000) loss: 1.890223
# (Time 3.17 sec; Iteration 761 / 16000) loss: 1.888057
# (Time 3.21 sec; Iteration 771 / 16000) loss: 2.004965
# (Time 3.24 sec; Iteration 781 / 16000) loss: 1.909985
# (Time 3.28 sec; Iteration 791 / 16000) loss: 1.998693
# (Epoch 1 / 20) train acc: 0.357000; val_acc: 0.311700
# (Time 3.50 sec; Iteration 801 / 16000) loss: 2.070176
# (Time 3.53 sec; Iteration 811 / 16000) loss: 1.835974
# (Time 3.57 sec; Iteration 821 / 16000) loss: 1.802541
# (Time 3.61 sec; Iteration 831 / 16000) loss: 1.964127
# (Time 3.65 sec; Iteration 841 / 16000) loss: 1.738553
# (Time 3.68 sec; Iteration 851 / 16000) loss: 1.797455
# (Time 3.72 sec; Iteration 861 / 16000) loss: 1.903744
# (Time 3.75 sec; Iteration 871 / 16000) loss: 1.911206
# (Time 3.79 sec; Iteration 881 / 16000) loss: 1.891654
# (Time 3.83 sec; Iteration 891 / 16000) loss: 1.973666
# (Time 3.87 sec; Iteration 901 / 16000) loss: 1.785903
# (Time 3.91 sec; Iteration 911 / 16000) loss: 1.799608
# (Time 3.95 sec; Iteration 921 / 16000) loss: 1.761389
# (Time 3.98 sec; Iteration 931 / 16000) loss: 1.797975
# (Time 4.02 sec; Iteration 941 / 16000) loss: 1.745788
# (Time 4.06 sec; Iteration 951 / 16000) loss: 1.805967
# (Time 4.09 sec; Iteration 961 / 16000) loss: 1.881766
# (Time 4.13 sec; Iteration 971 / 16000) loss: 1.886389
# (Time 4.17 sec; Iteration 981 / 16000) loss: 1.820769
# (Time 4.20 sec; Iteration 991 / 16000) loss: 1.919405
# (Time 4.24 sec; Iteration 1001 / 16000) loss: 1.826202
# (Time 4.27 sec; Iteration 1011 / 16000) loss: 1.925912
# (Time 4.31 sec; Iteration 1021 / 16000) loss: 1.680581
# (Time 4.35 sec; Iteration 1031 / 16000) loss: 1.562581
# (Time 4.39 sec; Iteration 1041 / 16000) loss: 1.783587
# (Time 4.43 sec; Iteration 1051 / 16000) loss: 1.807762
# (Time 4.46 sec; Iteration 1061 / 16000) loss: 2.042062
# (Time 4.50 sec; Iteration 1071 / 16000) loss: 2.073240
# (Time 4.54 sec; Iteration 1081 / 16000) loss: 1.836817
# (Time 4.58 sec; Iteration 1091 / 16000) loss: 1.825209
# (Time 4.62 sec; Iteration 1101 / 16000) loss: 1.730099
# (Time 4.66 sec; Iteration 1111 / 16000) loss: 1.990405
# (Time 4.70 sec; Iteration 1121 / 16000) loss: 1.793385
# (Time 4.74 sec; Iteration 1131 / 16000) loss: 1.784976
# (Time 4.78 sec; Iteration 1141 / 16000) loss: 1.802259
# (Time 4.81 sec; Iteration 1151 / 16000) loss: 1.754958
# (Time 4.85 sec; Iteration 1161 / 16000) loss: 1.909740
# (Time 4.90 sec; Iteration 1171 / 16000) loss: 1.845610
# (Time 4.93 sec; Iteration 1181 / 16000) loss: 2.169723
# (Time 4.97 sec; Iteration 1191 / 16000) loss: 1.762775
# (Time 5.02 sec; Iteration 1201 / 16000) loss: 1.854346
# (Time 5.05 sec; Iteration 1211 / 16000) loss: 1.839460
# (Time 5.09 sec; Iteration 1221 / 16000) loss: 1.917418
# (Time 5.13 sec; Iteration 1231 / 16000) loss: 1.774488
# (Time 5.17 sec; Iteration 1241 / 16000) loss: 1.641408
# (Time 5.21 sec; Iteration 1251 / 16000) loss: 1.858325
# (Time 5.25 sec; Iteration 1261 / 16000) loss: 1.775387
# (Time 5.29 sec; Iteration 1271 / 16000) loss: 1.592461
# (Time 5.33 sec; Iteration 1281 / 16000) loss: 1.740950
# (Time 5.37 sec; Iteration 1291 / 16000) loss: 1.885959
# (Time 5.40 sec; Iteration 1301 / 16000) loss: 1.783744
# (Time 5.44 sec; Iteration 1311 / 16000) loss: 1.742625
# (Time 5.47 sec; Iteration 1321 / 16000) loss: 1.840781
# (Time 5.51 sec; Iteration 1331 / 16000) loss: 1.809866
# (Time 5.54 sec; Iteration 1341 / 16000) loss: 1.835025
# (Time 5.58 sec; Iteration 1351 / 16000) loss: 1.878589
# (Time 5.62 sec; Iteration 1361 / 16000) loss: 1.791116
# (Time 5.65 sec; Iteration 1371 / 16000) loss: 1.804971
# (Time 5.70 sec; Iteration 1381 / 16000) loss: 1.727077
# (Time 5.73 sec; Iteration 1391 / 16000) loss: 1.704223
# (Time 5.77 sec; Iteration 1401 / 16000) loss: 1.764943
# (Time 5.81 sec; Iteration 1411 / 16000) loss: 1.825632
# (Time 5.84 sec; Iteration 1421 / 16000) loss: 1.639388
# (Time 5.88 sec; Iteration 1431 / 16000) loss: 1.684157
# (Time 5.92 sec; Iteration 1441 / 16000) loss: 1.636128
# (Time 5.95 sec; Iteration 1451 / 16000) loss: 1.725333
# (Time 5.99 sec; Iteration 1461 / 16000) loss: 1.794546
# (Time 6.03 sec; Iteration 1471 / 16000) loss: 1.605975
# (Time 6.06 sec; Iteration 1481 / 16000) loss: 1.848097
# (Time 6.10 sec; Iteration 1491 / 16000) loss: 1.695483
# (Time 6.13 sec; Iteration 1501 / 16000) loss: 1.801563
# (Time 6.17 sec; Iteration 1511 / 16000) loss: 1.722096
# (Time 6.20 sec; Iteration 1521 / 16000) loss: 1.634715
# (Time 6.24 sec; Iteration 1531 / 16000) loss: 1.781770
# (Time 6.28 sec; Iteration 1541 / 16000) loss: 1.727482
# (Time 6.31 sec; Iteration 1551 / 16000) loss: 1.816906
# (Time 6.35 sec; Iteration 1561 / 16000) loss: 1.980338
# (Time 6.38 sec; Iteration 1571 / 16000) loss: 1.823082
# (Time 6.42 sec; Iteration 1581 / 16000) loss: 1.657299
# (Time 6.46 sec; Iteration 1591 / 16000) loss: 1.654561
# (Epoch 2 / 20) train acc: 0.397000; val_acc: 0.373100
# (Time 6.67 sec; Iteration 1601 / 16000) loss: 1.668346
# (Time 6.70 sec; Iteration 1611 / 16000) loss: 1.650588
# (Time 6.74 sec; Iteration 1621 / 16000) loss: 1.580801
# (Time 6.78 sec; Iteration 1631 / 16000) loss: 1.819202
# (Time 6.81 sec; Iteration 1641 / 16000) loss: 1.736910
# (Time 6.85 sec; Iteration 1651 / 16000) loss: 1.703482
# (Time 6.89 sec; Iteration 1661 / 16000) loss: 1.690336
# (Time 6.92 sec; Iteration 1671 / 16000) loss: 1.465829
# (Time 6.95 sec; Iteration 1681 / 16000) loss: 1.789710
# (Time 6.99 sec; Iteration 1691 / 16000) loss: 1.630901
# (Time 7.03 sec; Iteration 1701 / 16000) loss: 1.655515
# (Time 7.06 sec; Iteration 1711 / 16000) loss: 1.379588
# (Time 7.10 sec; Iteration 1721 / 16000) loss: 1.555240
# (Time 7.13 sec; Iteration 1731 / 16000) loss: 1.699675
# (Time 7.17 sec; Iteration 1741 / 16000) loss: 1.534161
# (Time 7.21 sec; Iteration 1751 / 16000) loss: 1.438082
# (Time 7.24 sec; Iteration 1761 / 16000) loss: 1.876336
# (Time 7.28 sec; Iteration 1771 / 16000) loss: 1.625580
# (Time 7.32 sec; Iteration 1781 / 16000) loss: 1.485522
# (Time 7.36 sec; Iteration 1791 / 16000) loss: 1.614832
# (Time 7.39 sec; Iteration 1801 / 16000) loss: 1.812790
# (Time 7.43 sec; Iteration 1811 / 16000) loss: 1.705046
# (Time 7.46 sec; Iteration 1821 / 16000) loss: 1.695414
# (Time 7.49 sec; Iteration 1831 / 16000) loss: 1.796217
# (Time 7.53 sec; Iteration 1841 / 16000) loss: 1.948355
# (Time 7.56 sec; Iteration 1851 / 16000) loss: 1.741247
# (Time 7.61 sec; Iteration 1861 / 16000) loss: 1.839018
# (Time 7.64 sec; Iteration 1871 / 16000) loss: 2.013528
# (Time 7.68 sec; Iteration 1881 / 16000) loss: 1.647241
# (Time 7.71 sec; Iteration 1891 / 16000) loss: 1.565377
# (Time 7.74 sec; Iteration 1901 / 16000) loss: 1.698597
# (Time 7.78 sec; Iteration 1911 / 16000) loss: 1.601263
# (Time 7.81 sec; Iteration 1921 / 16000) loss: 1.791620
# (Time 7.85 sec; Iteration 1931 / 16000) loss: 1.794590
# (Time 7.88 sec; Iteration 1941 / 16000) loss: 1.471137
# (Time 7.92 sec; Iteration 1951 / 16000) loss: 1.631551
# (Time 7.96 sec; Iteration 1961 / 16000) loss: 1.762615
# (Time 7.99 sec; Iteration 1971 / 16000) loss: 1.615265
# (Time 8.02 sec; Iteration 1981 / 16000) loss: 1.584644
# (Time 8.06 sec; Iteration 1991 / 16000) loss: 1.851430
# (Time 8.09 sec; Iteration 2001 / 16000) loss: 1.579929
# (Time 8.13 sec; Iteration 2011 / 16000) loss: 1.734971
# (Time 8.17 sec; Iteration 2021 / 16000) loss: 1.848762
# (Time 8.20 sec; Iteration 2031 / 16000) loss: 1.533912
# (Time 8.24 sec; Iteration 2041 / 16000) loss: 1.656507
# (Time 8.27 sec; Iteration 2051 / 16000) loss: 1.740346
# (Time 8.31 sec; Iteration 2061 / 16000) loss: 1.815112
# (Time 8.34 sec; Iteration 2071 / 16000) loss: 1.857454
# (Time 8.38 sec; Iteration 2081 / 16000) loss: 1.673818
# (Time 8.41 sec; Iteration 2091 / 16000) loss: 1.551232
# (Time 8.45 sec; Iteration 2101 / 16000) loss: 1.561959
# (Time 8.49 sec; Iteration 2111 / 16000) loss: 1.759813
# (Time 8.52 sec; Iteration 2121 / 16000) loss: 1.688231
# (Time 8.56 sec; Iteration 2131 / 16000) loss: 1.644444
# (Time 8.59 sec; Iteration 2141 / 16000) loss: 1.648600
# (Time 8.63 sec; Iteration 2151 / 16000) loss: 1.750161
# (Time 8.66 sec; Iteration 2161 / 16000) loss: 1.689873
# (Time 8.70 sec; Iteration 2171 / 16000) loss: 1.653739
# (Time 8.73 sec; Iteration 2181 / 16000) loss: 1.597552
# (Time 8.77 sec; Iteration 2191 / 16000) loss: 1.626884
# (Time 8.80 sec; Iteration 2201 / 16000) loss: 1.599753
# (Time 8.84 sec; Iteration 2211 / 16000) loss: 1.678771
# (Time 8.88 sec; Iteration 2221 / 16000) loss: 1.694423
# (Time 8.91 sec; Iteration 2231 / 16000) loss: 1.555711
# (Time 8.95 sec; Iteration 2241 / 16000) loss: 1.729081
# (Time 8.98 sec; Iteration 2251 / 16000) loss: 1.678342
# (Time 9.02 sec; Iteration 2261 / 16000) loss: 1.562245
# (Time 9.06 sec; Iteration 2271 / 16000) loss: 1.730391
# (Time 9.09 sec; Iteration 2281 / 16000) loss: 1.676396
# (Time 9.13 sec; Iteration 2291 / 16000) loss: 1.662136
# (Time 9.16 sec; Iteration 2301 / 16000) loss: 1.846086
# (Time 9.20 sec; Iteration 2311 / 16000) loss: 1.642401
# (Time 9.24 sec; Iteration 2321 / 16000) loss: 1.372360
# (Time 9.27 sec; Iteration 2331 / 16000) loss: 1.553280
# (Time 9.31 sec; Iteration 2341 / 16000) loss: 1.757950
# (Time 9.34 sec; Iteration 2351 / 16000) loss: 1.531328
# (Time 9.38 sec; Iteration 2361 / 16000) loss: 1.643810
# (Time 9.41 sec; Iteration 2371 / 16000) loss: 1.658107
# (Time 9.45 sec; Iteration 2381 / 16000) loss: 1.521757
# (Time 9.49 sec; Iteration 2391 / 16000) loss: 1.761265
# (Epoch 3 / 20) train acc: 0.406000; val_acc: 0.414200
# (Time 9.70 sec; Iteration 2401 / 16000) loss: 1.910036
# (Time 9.74 sec; Iteration 2411 / 16000) loss: 1.702605
# (Time 9.77 sec; Iteration 2421 / 16000) loss: 1.502238
# (Time 9.81 sec; Iteration 2431 / 16000) loss: 1.475154
# (Time 9.84 sec; Iteration 2441 / 16000) loss: 1.532270
# (Time 9.88 sec; Iteration 2451 / 16000) loss: 1.558347
# (Time 9.92 sec; Iteration 2461 / 16000) loss: 1.758558
# (Time 9.96 sec; Iteration 2471 / 16000) loss: 1.583282
# (Time 9.99 sec; Iteration 2481 / 16000) loss: 1.472554
# (Time 10.03 sec; Iteration 2491 / 16000) loss: 1.661303
# (Time 10.06 sec; Iteration 2501 / 16000) loss: 1.524800
# (Time 10.10 sec; Iteration 2511 / 16000) loss: 1.430340
# (Time 10.14 sec; Iteration 2521 / 16000) loss: 1.527512
# (Time 10.17 sec; Iteration 2531 / 16000) loss: 1.558190
# (Time 10.21 sec; Iteration 2541 / 16000) loss: 1.683963
# (Time 10.24 sec; Iteration 2551 / 16000) loss: 1.541030
# (Time 10.28 sec; Iteration 2561 / 16000) loss: 1.480028
# (Time 10.31 sec; Iteration 2571 / 16000) loss: 1.641655
# (Time 10.35 sec; Iteration 2581 / 16000) loss: 1.482501
# (Time 10.38 sec; Iteration 2591 / 16000) loss: 1.608684
# (Time 10.42 sec; Iteration 2601 / 16000) loss: 1.782282
# (Time 10.46 sec; Iteration 2611 / 16000) loss: 1.552549
# (Time 10.50 sec; Iteration 2621 / 16000) loss: 1.532185
# (Time 10.53 sec; Iteration 2631 / 16000) loss: 1.426109
# (Time 10.56 sec; Iteration 2641 / 16000) loss: 1.497825
# (Time 10.60 sec; Iteration 2651 / 16000) loss: 1.546302
# (Time 10.64 sec; Iteration 2661 / 16000) loss: 1.851918
# (Time 10.67 sec; Iteration 2671 / 16000) loss: 1.640081
# (Time 10.71 sec; Iteration 2681 / 16000) loss: 1.629165
# (Time 10.74 sec; Iteration 2691 / 16000) loss: 1.566324
# (Time 10.77 sec; Iteration 2701 / 16000) loss: 1.562332
# (Time 10.81 sec; Iteration 2711 / 16000) loss: 1.515047
# (Time 10.85 sec; Iteration 2721 / 16000) loss: 1.700080
# (Time 10.89 sec; Iteration 2731 / 16000) loss: 1.460229
# (Time 10.93 sec; Iteration 2741 / 16000) loss: 1.674631
# (Time 10.96 sec; Iteration 2751 / 16000) loss: 1.678564
# (Time 11.00 sec; Iteration 2761 / 16000) loss: 1.831088
# (Time 11.03 sec; Iteration 2771 / 16000) loss: 1.618105
# (Time 11.06 sec; Iteration 2781 / 16000) loss: 1.499430
# (Time 11.10 sec; Iteration 2791 / 16000) loss: 1.672801
# (Time 11.13 sec; Iteration 2801 / 16000) loss: 1.448298
# (Time 11.17 sec; Iteration 2811 / 16000) loss: 1.773858
# (Time 11.20 sec; Iteration 2821 / 16000) loss: 1.331165
# (Time 11.24 sec; Iteration 2831 / 16000) loss: 1.729933
# (Time 11.28 sec; Iteration 2841 / 16000) loss: 1.582372
# (Time 11.31 sec; Iteration 2851 / 16000) loss: 1.539639
# (Time 11.35 sec; Iteration 2861 / 16000) loss: 1.636546
# (Time 11.38 sec; Iteration 2871 / 16000) loss: 1.641334
# (Time 11.42 sec; Iteration 2881 / 16000) loss: 1.467742
# (Time 11.46 sec; Iteration 2891 / 16000) loss: 1.346820
# (Time 11.49 sec; Iteration 2901 / 16000) loss: 1.691475
# (Time 11.53 sec; Iteration 2911 / 16000) loss: 1.396040
# (Time 11.56 sec; Iteration 2921 / 16000) loss: 1.646857
# (Time 11.60 sec; Iteration 2931 / 16000) loss: 1.443001
# (Time 11.64 sec; Iteration 2941 / 16000) loss: 1.337681
# (Time 11.68 sec; Iteration 2951 / 16000) loss: 1.453696
# (Time 11.71 sec; Iteration 2961 / 16000) loss: 1.560115
# (Time 11.74 sec; Iteration 2971 / 16000) loss: 1.344884
# (Time 11.78 sec; Iteration 2981 / 16000) loss: 1.854119
# (Time 11.81 sec; Iteration 2991 / 16000) loss: 1.434984
# (Time 11.85 sec; Iteration 3001 / 16000) loss: 1.522017
# (Time 11.89 sec; Iteration 3011 / 16000) loss: 1.743377
# (Time 11.93 sec; Iteration 3021 / 16000) loss: 1.779587
# (Time 11.96 sec; Iteration 3031 / 16000) loss: 1.596085
# (Time 12.00 sec; Iteration 3041 / 16000) loss: 1.552550
# (Time 12.03 sec; Iteration 3051 / 16000) loss: 1.699613
# (Time 12.06 sec; Iteration 3061 / 16000) loss: 1.528794
# (Time 12.10 sec; Iteration 3071 / 16000) loss: 1.539836
# (Time 12.13 sec; Iteration 3081 / 16000) loss: 1.271437
# (Time 12.17 sec; Iteration 3091 / 16000) loss: 1.558720
# (Time 12.21 sec; Iteration 3101 / 16000) loss: 1.766335
# (Time 12.24 sec; Iteration 3111 / 16000) loss: 1.406726
# (Time 12.28 sec; Iteration 3121 / 16000) loss: 1.450544
# (Time 12.31 sec; Iteration 3131 / 16000) loss: 1.639590
# (Time 12.35 sec; Iteration 3141 / 16000) loss: 1.499217
# (Time 12.38 sec; Iteration 3151 / 16000) loss: 1.619092
# (Time 12.42 sec; Iteration 3161 / 16000) loss: 1.505328
# (Time 12.45 sec; Iteration 3171 / 16000) loss: 1.681250
# (Time 12.49 sec; Iteration 3181 / 16000) loss: 1.775562
# (Time 12.53 sec; Iteration 3191 / 16000) loss: 1.807633
# (Epoch 4 / 20) train acc: 0.443000; val_acc: 0.441700
# (Time 12.74 sec; Iteration 3201 / 16000) loss: 1.618842
# (Time 12.77 sec; Iteration 3211 / 16000) loss: 1.975716
# (Time 12.81 sec; Iteration 3221 / 16000) loss: 1.473314
# (Time 12.85 sec; Iteration 3231 / 16000) loss: 1.285764
# (Time 12.88 sec; Iteration 3241 / 16000) loss: 1.293223
# (Time 12.92 sec; Iteration 3251 / 16000) loss: 1.573224
# (Time 12.95 sec; Iteration 3261 / 16000) loss: 1.714043
# (Time 12.99 sec; Iteration 3271 / 16000) loss: 1.456863
# (Time 13.02 sec; Iteration 3281 / 16000) loss: 1.879936
# (Time 13.06 sec; Iteration 3291 / 16000) loss: 1.634483
# (Time 13.09 sec; Iteration 3301 / 16000) loss: 1.518570
# (Time 13.14 sec; Iteration 3311 / 16000) loss: 1.478252
# (Time 13.17 sec; Iteration 3321 / 16000) loss: 1.275108
# (Time 13.20 sec; Iteration 3331 / 16000) loss: 1.609662
# (Time 13.24 sec; Iteration 3341 / 16000) loss: 1.597041
# (Time 13.27 sec; Iteration 3351 / 16000) loss: 1.354459
# (Time 13.31 sec; Iteration 3361 / 16000) loss: 1.558332
# (Time 13.35 sec; Iteration 3371 / 16000) loss: 1.788910
# (Time 13.38 sec; Iteration 3381 / 16000) loss: 1.567823
# (Time 13.42 sec; Iteration 3391 / 16000) loss: 1.475584
# (Time 13.45 sec; Iteration 3401 / 16000) loss: 1.518043
# (Time 13.49 sec; Iteration 3411 / 16000) loss: 1.539235
# (Time 13.52 sec; Iteration 3421 / 16000) loss: 1.622614
# (Time 13.56 sec; Iteration 3431 / 16000) loss: 1.470044
# (Time 13.59 sec; Iteration 3441 / 16000) loss: 1.638092
# (Time 13.63 sec; Iteration 3451 / 16000) loss: 1.703703
# (Time 13.67 sec; Iteration 3461 / 16000) loss: 1.702906
# (Time 13.70 sec; Iteration 3471 / 16000) loss: 1.615406
# (Time 13.74 sec; Iteration 3481 / 16000) loss: 1.388135
# (Time 13.77 sec; Iteration 3491 / 16000) loss: 1.509361
# (Time 13.81 sec; Iteration 3501 / 16000) loss: 1.439060
# (Time 13.85 sec; Iteration 3511 / 16000) loss: 1.397976
# (Time 13.88 sec; Iteration 3521 / 16000) loss: 1.462664
# (Time 13.92 sec; Iteration 3531 / 16000) loss: 1.560240
# (Time 13.96 sec; Iteration 3541 / 16000) loss: 1.425588
# (Time 13.99 sec; Iteration 3551 / 16000) loss: 1.517476
# (Time 14.03 sec; Iteration 3561 / 16000) loss: 1.341530
# (Time 14.07 sec; Iteration 3571 / 16000) loss: 1.415645
# (Time 14.10 sec; Iteration 3581 / 16000) loss: 1.515778
# (Time 14.14 sec; Iteration 3591 / 16000) loss: 1.780856
# (Time 14.18 sec; Iteration 3601 / 16000) loss: 1.557954
# (Time 14.21 sec; Iteration 3611 / 16000) loss: 1.667827
# (Time 14.25 sec; Iteration 3621 / 16000) loss: 1.474584
# (Time 14.29 sec; Iteration 3631 / 16000) loss: 1.506595
# (Time 14.32 sec; Iteration 3641 / 16000) loss: 1.437122
# (Time 14.36 sec; Iteration 3651 / 16000) loss: 1.350148
# (Time 14.39 sec; Iteration 3661 / 16000) loss: 1.469977
# (Time 14.43 sec; Iteration 3671 / 16000) loss: 1.867669
# (Time 14.46 sec; Iteration 3681 / 16000) loss: 1.704624
# (Time 14.50 sec; Iteration 3691 / 16000) loss: 1.575810
# (Time 14.54 sec; Iteration 3701 / 16000) loss: 1.531574
# (Time 14.57 sec; Iteration 3711 / 16000) loss: 1.240934
# (Time 14.61 sec; Iteration 3721 / 16000) loss: 1.342601
# (Time 14.64 sec; Iteration 3731 / 16000) loss: 1.334792
# (Time 14.68 sec; Iteration 3741 / 16000) loss: 1.693677
# (Time 14.71 sec; Iteration 3751 / 16000) loss: 1.663670
# (Time 14.75 sec; Iteration 3761 / 16000) loss: 1.277536
# (Time 14.79 sec; Iteration 3771 / 16000) loss: 1.473686
# (Time 14.82 sec; Iteration 3781 / 16000) loss: 1.420063
# (Time 14.86 sec; Iteration 3791 / 16000) loss: 1.598397
# (Time 14.89 sec; Iteration 3801 / 16000) loss: 1.372180
# (Time 14.93 sec; Iteration 3811 / 16000) loss: 1.451284
# (Time 14.96 sec; Iteration 3821 / 16000) loss: 1.669601
# (Time 14.99 sec; Iteration 3831 / 16000) loss: 1.729493
# (Time 15.04 sec; Iteration 3841 / 16000) loss: 1.571656
# (Time 15.07 sec; Iteration 3851 / 16000) loss: 1.505679
# (Time 15.11 sec; Iteration 3861 / 16000) loss: 1.732410
# (Time 15.14 sec; Iteration 3871 / 16000) loss: 1.702008
# (Time 15.18 sec; Iteration 3881 / 16000) loss: 1.579177
# (Time 15.21 sec; Iteration 3891 / 16000) loss: 1.543384
# (Time 15.25 sec; Iteration 3901 / 16000) loss: 1.582283
# (Time 15.29 sec; Iteration 3911 / 16000) loss: 1.350860
# (Time 15.32 sec; Iteration 3921 / 16000) loss: 1.502066
# (Time 15.35 sec; Iteration 3931 / 16000) loss: 1.697511
# (Time 15.40 sec; Iteration 3941 / 16000) loss: 1.607968
# (Time 15.43 sec; Iteration 3951 / 16000) loss: 1.822626
# (Time 15.46 sec; Iteration 3961 / 16000) loss: 1.291385
# (Time 15.50 sec; Iteration 3971 / 16000) loss: 1.709673
# (Time 15.53 sec; Iteration 3981 / 16000) loss: 1.467262
# (Time 15.57 sec; Iteration 3991 / 16000) loss: 1.888995
# (Epoch 5 / 20) train acc: 0.506000; val_acc: 0.456400
# (Time 15.78 sec; Iteration 4001 / 16000) loss: 1.513784
# (Time 15.81 sec; Iteration 4011 / 16000) loss: 1.404355
# (Time 15.85 sec; Iteration 4021 / 16000) loss: 1.751260
# (Time 15.88 sec; Iteration 4031 / 16000) loss: 1.754489
# (Time 15.92 sec; Iteration 4041 / 16000) loss: 1.289629
# (Time 15.95 sec; Iteration 4051 / 16000) loss: 1.450605
# (Time 15.99 sec; Iteration 4061 / 16000) loss: 1.458452
# (Time 16.02 sec; Iteration 4071 / 16000) loss: 1.246447
# (Time 16.05 sec; Iteration 4081 / 16000) loss: 1.579232
# (Time 16.09 sec; Iteration 4091 / 16000) loss: 1.428433
# (Time 16.14 sec; Iteration 4101 / 16000) loss: 1.575179
# (Time 16.16 sec; Iteration 4111 / 16000) loss: 1.460011
# (Time 16.20 sec; Iteration 4121 / 16000) loss: 1.522895
# (Time 16.24 sec; Iteration 4131 / 16000) loss: 1.228793
# (Time 16.28 sec; Iteration 4141 / 16000) loss: 1.590961
# (Time 16.31 sec; Iteration 4151 / 16000) loss: 1.162721
# (Time 16.34 sec; Iteration 4161 / 16000) loss: 1.506153
# (Time 16.38 sec; Iteration 4171 / 16000) loss: 1.276434
# (Time 16.41 sec; Iteration 4181 / 16000) loss: 1.259118
# (Time 16.45 sec; Iteration 4191 / 16000) loss: 1.329767
# (Time 16.49 sec; Iteration 4201 / 16000) loss: 1.650483
# (Time 16.52 sec; Iteration 4211 / 16000) loss: 1.475500
# (Time 16.56 sec; Iteration 4221 / 16000) loss: 1.519528
# (Time 16.60 sec; Iteration 4231 / 16000) loss: 1.224678
# (Time 16.63 sec; Iteration 4241 / 16000) loss: 1.392226
# (Time 16.67 sec; Iteration 4251 / 16000) loss: 1.304243
# (Time 16.70 sec; Iteration 4261 / 16000) loss: 1.436606
# (Time 16.74 sec; Iteration 4271 / 16000) loss: 1.316391
# (Time 16.77 sec; Iteration 4281 / 16000) loss: 1.471696
# (Time 16.81 sec; Iteration 4291 / 16000) loss: 1.336741
# (Time 16.84 sec; Iteration 4301 / 16000) loss: 1.469574
# (Time 16.88 sec; Iteration 4311 / 16000) loss: 1.168055
# (Time 16.92 sec; Iteration 4321 / 16000) loss: 1.973491
# (Time 16.95 sec; Iteration 4331 / 16000) loss: 1.533034
# (Time 16.99 sec; Iteration 4341 / 16000) loss: 1.749857
# (Time 17.03 sec; Iteration 4351 / 16000) loss: 1.460771
# (Time 17.07 sec; Iteration 4361 / 16000) loss: 1.200825
# (Time 17.10 sec; Iteration 4371 / 16000) loss: 1.346158
# (Time 17.14 sec; Iteration 4381 / 16000) loss: 1.316888
# (Time 17.17 sec; Iteration 4391 / 16000) loss: 1.257703
# (Time 17.20 sec; Iteration 4401 / 16000) loss: 1.448408
# (Time 17.24 sec; Iteration 4411 / 16000) loss: 1.270815
# (Time 17.28 sec; Iteration 4421 / 16000) loss: 1.346680
# (Time 17.32 sec; Iteration 4431 / 16000) loss: 1.527507
# (Time 17.36 sec; Iteration 4441 / 16000) loss: 1.478946
# (Time 17.39 sec; Iteration 4451 / 16000) loss: 1.872728
# (Time 17.43 sec; Iteration 4461 / 16000) loss: 1.509387
# (Time 17.46 sec; Iteration 4471 / 16000) loss: 1.630986
# (Time 17.50 sec; Iteration 4481 / 16000) loss: 1.707381
# (Time 17.54 sec; Iteration 4491 / 16000) loss: 1.357909
# (Time 17.57 sec; Iteration 4501 / 16000) loss: 1.407405
# (Time 17.61 sec; Iteration 4511 / 16000) loss: 1.369141
# (Time 17.64 sec; Iteration 4521 / 16000) loss: 1.562336
# (Time 17.68 sec; Iteration 4531 / 16000) loss: 1.639510
# (Time 17.71 sec; Iteration 4541 / 16000) loss: 1.354881
# (Time 17.75 sec; Iteration 4551 / 16000) loss: 1.418231
# (Time 17.79 sec; Iteration 4561 / 16000) loss: 1.554118
# (Time 17.82 sec; Iteration 4571 / 16000) loss: 1.234575
# (Time 17.86 sec; Iteration 4581 / 16000) loss: 1.619089
# (Time 17.89 sec; Iteration 4591 / 16000) loss: 1.406406
# (Time 17.93 sec; Iteration 4601 / 16000) loss: 1.390047
# (Time 17.96 sec; Iteration 4611 / 16000) loss: 1.288165
# (Time 18.00 sec; Iteration 4621 / 16000) loss: 1.494214
# (Time 18.04 sec; Iteration 4631 / 16000) loss: 1.012477
# (Time 18.07 sec; Iteration 4641 / 16000) loss: 1.553627
# (Time 18.11 sec; Iteration 4651 / 16000) loss: 1.281201
# (Time 18.14 sec; Iteration 4661 / 16000) loss: 1.594471
# (Time 18.18 sec; Iteration 4671 / 16000) loss: 1.818600
# (Time 18.21 sec; Iteration 4681 / 16000) loss: 1.496659
# (Time 18.25 sec; Iteration 4691 / 16000) loss: 1.620427
# (Time 18.29 sec; Iteration 4701 / 16000) loss: 1.480585
# (Time 18.31 sec; Iteration 4711 / 16000) loss: 1.359455
# (Time 18.36 sec; Iteration 4721 / 16000) loss: 1.627979
# (Time 18.40 sec; Iteration 4731 / 16000) loss: 1.563604
# (Time 18.43 sec; Iteration 4741 / 16000) loss: 1.241373
# (Time 18.46 sec; Iteration 4751 / 16000) loss: 1.486130
# (Time 18.50 sec; Iteration 4761 / 16000) loss: 1.413033
# (Time 18.53 sec; Iteration 4771 / 16000) loss: 1.367996
# (Time 18.57 sec; Iteration 4781 / 16000) loss: 1.251433
# (Time 18.60 sec; Iteration 4791 / 16000) loss: 1.278200
# (Epoch 6 / 20) train acc: 0.488000; val_acc: 0.461300
# (Time 18.81 sec; Iteration 4801 / 16000) loss: 1.303730
# (Time 18.85 sec; Iteration 4811 / 16000) loss: 1.800984
# (Time 18.89 sec; Iteration 4821 / 16000) loss: 1.460781
# (Time 18.92 sec; Iteration 4831 / 16000) loss: 1.441835
# (Time 18.95 sec; Iteration 4841 / 16000) loss: 1.475592
# (Time 18.99 sec; Iteration 4851 / 16000) loss: 1.596985
# (Time 19.02 sec; Iteration 4861 / 16000) loss: 1.492655
# (Time 19.06 sec; Iteration 4871 / 16000) loss: 1.538282
# (Time 19.10 sec; Iteration 4881 / 16000) loss: 1.343342
# (Time 19.13 sec; Iteration 4891 / 16000) loss: 1.560009
# (Time 19.17 sec; Iteration 4901 / 16000) loss: 1.255326
# (Time 19.20 sec; Iteration 4911 / 16000) loss: 1.356704
# (Time 19.24 sec; Iteration 4921 / 16000) loss: 1.309713
# (Time 19.27 sec; Iteration 4931 / 16000) loss: 1.293835
# (Time 19.31 sec; Iteration 4941 / 16000) loss: 1.188779
# (Time 19.34 sec; Iteration 4951 / 16000) loss: 1.604819
# (Time 19.38 sec; Iteration 4961 / 16000) loss: 1.192793
# (Time 19.42 sec; Iteration 4971 / 16000) loss: 1.357664
# (Time 19.45 sec; Iteration 4981 / 16000) loss: 1.383110
# (Time 19.49 sec; Iteration 4991 / 16000) loss: 1.687435
# (Time 19.52 sec; Iteration 5001 / 16000) loss: 1.522415
# (Time 19.56 sec; Iteration 5011 / 16000) loss: 1.428638
# (Time 19.60 sec; Iteration 5021 / 16000) loss: 1.322318
# (Time 19.64 sec; Iteration 5031 / 16000) loss: 1.617040
# (Time 19.67 sec; Iteration 5041 / 16000) loss: 1.629180
# (Time 19.70 sec; Iteration 5051 / 16000) loss: 1.203835
# (Time 19.74 sec; Iteration 5061 / 16000) loss: 1.588646
# (Time 19.78 sec; Iteration 5071 / 16000) loss: 1.196633
# (Time 19.81 sec; Iteration 5081 / 16000) loss: 1.602287
# (Time 19.84 sec; Iteration 5091 / 16000) loss: 1.417298
# (Time 19.88 sec; Iteration 5101 / 16000) loss: 1.272125
# (Time 19.91 sec; Iteration 5111 / 16000) loss: 1.346755
# (Time 19.95 sec; Iteration 5121 / 16000) loss: 1.779433
# (Time 19.98 sec; Iteration 5131 / 16000) loss: 1.365084
# (Time 20.02 sec; Iteration 5141 / 16000) loss: 1.315281
# (Time 20.05 sec; Iteration 5151 / 16000) loss: 1.517327
# (Time 20.09 sec; Iteration 5161 / 16000) loss: 1.485840
# (Time 20.12 sec; Iteration 5171 / 16000) loss: 1.749068
# (Time 20.16 sec; Iteration 5181 / 16000) loss: 1.393429
# (Time 20.20 sec; Iteration 5191 / 16000) loss: 1.360466
# (Time 20.23 sec; Iteration 5201 / 16000) loss: 1.557356
# (Time 20.27 sec; Iteration 5211 / 16000) loss: 1.318857
# (Time 20.30 sec; Iteration 5221 / 16000) loss: 1.682702
# (Time 20.34 sec; Iteration 5231 / 16000) loss: 1.458647
# (Time 20.37 sec; Iteration 5241 / 16000) loss: 1.667371
# (Time 20.41 sec; Iteration 5251 / 16000) loss: 1.343839
# (Time 20.45 sec; Iteration 5261 / 16000) loss: 1.330166
# (Time 20.48 sec; Iteration 5271 / 16000) loss: 1.514095
# (Time 20.52 sec; Iteration 5281 / 16000) loss: 1.402163
# (Time 20.55 sec; Iteration 5291 / 16000) loss: 1.292261
# (Time 20.59 sec; Iteration 5301 / 16000) loss: 1.179491
# (Time 20.63 sec; Iteration 5311 / 16000) loss: 1.488668
# (Time 20.66 sec; Iteration 5321 / 16000) loss: 1.365990
# (Time 20.70 sec; Iteration 5331 / 16000) loss: 1.299107
# (Time 20.73 sec; Iteration 5341 / 16000) loss: 1.619553
# (Time 20.77 sec; Iteration 5351 / 16000) loss: 1.533375
# (Time 20.80 sec; Iteration 5361 / 16000) loss: 1.414005
# (Time 20.84 sec; Iteration 5371 / 16000) loss: 0.992890
# (Time 20.88 sec; Iteration 5381 / 16000) loss: 1.509079
# (Time 20.91 sec; Iteration 5391 / 16000) loss: 1.340569
# (Time 20.95 sec; Iteration 5401 / 16000) loss: 1.327707
# (Time 20.98 sec; Iteration 5411 / 16000) loss: 1.306004
# (Time 21.02 sec; Iteration 5421 / 16000) loss: 1.520184
# (Time 21.06 sec; Iteration 5431 / 16000) loss: 1.364904
# (Time 21.09 sec; Iteration 5441 / 16000) loss: 1.061099
# (Time 21.13 sec; Iteration 5451 / 16000) loss: 1.288154
# (Time 21.16 sec; Iteration 5461 / 16000) loss: 1.466966
# (Time 21.20 sec; Iteration 5471 / 16000) loss: 1.384896
# (Time 21.24 sec; Iteration 5481 / 16000) loss: 1.259572
# (Time 21.27 sec; Iteration 5491 / 16000) loss: 1.553969
# (Time 21.31 sec; Iteration 5501 / 16000) loss: 1.667923
# (Time 21.34 sec; Iteration 5511 / 16000) loss: 1.668852
# (Time 21.38 sec; Iteration 5521 / 16000) loss: 1.457383
# (Time 21.40 sec; Iteration 5531 / 16000) loss: 1.303464
# (Time 21.44 sec; Iteration 5541 / 16000) loss: 1.406713
# (Time 21.48 sec; Iteration 5551 / 16000) loss: 1.601573
# (Time 21.52 sec; Iteration 5561 / 16000) loss: 1.349630
# (Time 21.55 sec; Iteration 5571 / 16000) loss: 1.359194
# (Time 21.59 sec; Iteration 5581 / 16000) loss: 1.570917
# (Time 21.62 sec; Iteration 5591 / 16000) loss: 1.279962
# (Epoch 7 / 20) train acc: 0.509000; val_acc: 0.474100
# (Time 21.83 sec; Iteration 5601 / 16000) loss: 1.263313
# (Time 21.86 sec; Iteration 5611 / 16000) loss: 1.107454
# (Time 21.90 sec; Iteration 5621 / 16000) loss: 1.530900
# (Time 21.94 sec; Iteration 5631 / 16000) loss: 1.416592
# (Time 21.97 sec; Iteration 5641 / 16000) loss: 1.154653
# (Time 22.00 sec; Iteration 5651 / 16000) loss: 1.481133
# (Time 22.04 sec; Iteration 5661 / 16000) loss: 1.337842
# (Time 22.08 sec; Iteration 5671 / 16000) loss: 1.551148
# (Time 22.11 sec; Iteration 5681 / 16000) loss: 1.456488
# (Time 22.14 sec; Iteration 5691 / 16000) loss: 1.215992
# (Time 22.18 sec; Iteration 5701 / 16000) loss: 1.351584
# (Time 22.21 sec; Iteration 5711 / 16000) loss: 1.446858
# (Time 22.25 sec; Iteration 5721 / 16000) loss: 1.613754
# (Time 22.29 sec; Iteration 5731 / 16000) loss: 1.425193
# (Time 22.32 sec; Iteration 5741 / 16000) loss: 1.315116
# (Time 22.36 sec; Iteration 5751 / 16000) loss: 1.234371
# (Time 22.39 sec; Iteration 5761 / 16000) loss: 1.394015
# (Time 22.43 sec; Iteration 5771 / 16000) loss: 1.469209
# (Time 22.46 sec; Iteration 5781 / 16000) loss: 1.605730
# (Time 22.50 sec; Iteration 5791 / 16000) loss: 1.301287
# (Time 22.53 sec; Iteration 5801 / 16000) loss: 1.236558
# (Time 22.57 sec; Iteration 5811 / 16000) loss: 1.324319
# (Time 22.61 sec; Iteration 5821 / 16000) loss: 1.459799
# (Time 22.64 sec; Iteration 5831 / 16000) loss: 1.389080
# (Time 22.68 sec; Iteration 5841 / 16000) loss: 1.590248
# (Time 22.71 sec; Iteration 5851 / 16000) loss: 1.688684
# (Time 22.75 sec; Iteration 5861 / 16000) loss: 1.489204
# (Time 22.78 sec; Iteration 5871 / 16000) loss: 1.513367
# (Time 22.82 sec; Iteration 5881 / 16000) loss: 1.306035
# (Time 22.86 sec; Iteration 5891 / 16000) loss: 1.201285
# (Time 22.89 sec; Iteration 5901 / 16000) loss: 1.352470
# (Time 22.93 sec; Iteration 5911 / 16000) loss: 1.448431
# (Time 22.96 sec; Iteration 5921 / 16000) loss: 1.448868
# (Time 23.00 sec; Iteration 5931 / 16000) loss: 1.438675
# (Time 23.03 sec; Iteration 5941 / 16000) loss: 1.232535
# (Time 23.07 sec; Iteration 5951 / 16000) loss: 1.007353
# (Time 23.10 sec; Iteration 5961 / 16000) loss: 1.615161
# (Time 23.14 sec; Iteration 5971 / 16000) loss: 1.346777
# (Time 23.18 sec; Iteration 5981 / 16000) loss: 1.462735
# (Time 23.21 sec; Iteration 5991 / 16000) loss: 1.302932
# (Time 23.25 sec; Iteration 6001 / 16000) loss: 1.656102
# (Time 23.28 sec; Iteration 6011 / 16000) loss: 1.130853
# (Time 23.32 sec; Iteration 6021 / 16000) loss: 1.533196
# (Time 23.35 sec; Iteration 6031 / 16000) loss: 1.454848
# (Time 23.39 sec; Iteration 6041 / 16000) loss: 1.265437
# (Time 23.42 sec; Iteration 6051 / 16000) loss: 1.775959
# (Time 23.45 sec; Iteration 6061 / 16000) loss: 1.317982
# (Time 23.49 sec; Iteration 6071 / 16000) loss: 1.425271
# (Time 23.53 sec; Iteration 6081 / 16000) loss: 1.587048
# (Time 23.57 sec; Iteration 6091 / 16000) loss: 1.627620
# (Time 23.60 sec; Iteration 6101 / 16000) loss: 1.280499
# (Time 23.64 sec; Iteration 6111 / 16000) loss: 1.319390
# (Time 23.67 sec; Iteration 6121 / 16000) loss: 1.575617
# (Time 23.70 sec; Iteration 6131 / 16000) loss: 1.364322
# (Time 23.74 sec; Iteration 6141 / 16000) loss: 1.239988
# (Time 23.78 sec; Iteration 6151 / 16000) loss: 1.342946
# (Time 23.81 sec; Iteration 6161 / 16000) loss: 1.197639
# (Time 23.85 sec; Iteration 6171 / 16000) loss: 1.084217
# (Time 23.89 sec; Iteration 6181 / 16000) loss: 1.792494
# (Time 23.92 sec; Iteration 6191 / 16000) loss: 1.252215
# (Time 23.96 sec; Iteration 6201 / 16000) loss: 1.404332
# (Time 23.99 sec; Iteration 6211 / 16000) loss: 1.449433
# (Time 24.03 sec; Iteration 6221 / 16000) loss: 1.282626
# (Time 24.07 sec; Iteration 6231 / 16000) loss: 1.372277
# (Time 24.10 sec; Iteration 6241 / 16000) loss: 1.417442
# (Time 24.14 sec; Iteration 6251 / 16000) loss: 1.286326
# (Time 24.17 sec; Iteration 6261 / 16000) loss: 1.447616
# (Time 24.21 sec; Iteration 6271 / 16000) loss: 1.296563
# (Time 24.24 sec; Iteration 6281 / 16000) loss: 1.234581
# (Time 24.28 sec; Iteration 6291 / 16000) loss: 1.276060
# (Time 24.31 sec; Iteration 6301 / 16000) loss: 1.449829
# (Time 24.35 sec; Iteration 6311 / 16000) loss: 1.209989
# (Time 24.38 sec; Iteration 6321 / 16000) loss: 1.311695
# (Time 24.42 sec; Iteration 6331 / 16000) loss: 1.122635
# (Time 24.45 sec; Iteration 6341 / 16000) loss: 1.428699
# (Time 24.49 sec; Iteration 6351 / 16000) loss: 1.443269
# (Time 24.52 sec; Iteration 6361 / 16000) loss: 1.332736
# (Time 24.56 sec; Iteration 6371 / 16000) loss: 1.131170
# (Time 24.60 sec; Iteration 6381 / 16000) loss: 1.233852
# (Time 24.63 sec; Iteration 6391 / 16000) loss: 1.382125
# (Epoch 8 / 20) train acc: 0.529000; val_acc: 0.483300
# (Time 24.84 sec; Iteration 6401 / 16000) loss: 1.197168
# (Time 24.88 sec; Iteration 6411 / 16000) loss: 1.389403
# (Time 24.91 sec; Iteration 6421 / 16000) loss: 1.444221
# (Time 24.95 sec; Iteration 6431 / 16000) loss: 1.389756
# (Time 24.99 sec; Iteration 6441 / 16000) loss: 1.396947
# (Time 25.02 sec; Iteration 6451 / 16000) loss: 1.181962
# (Time 25.06 sec; Iteration 6461 / 16000) loss: 1.287170
# (Time 25.09 sec; Iteration 6471 / 16000) loss: 1.241051
# (Time 25.13 sec; Iteration 6481 / 16000) loss: 1.314994
# (Time 25.16 sec; Iteration 6491 / 16000) loss: 1.410805
# (Time 25.20 sec; Iteration 6501 / 16000) loss: 1.310557
# (Time 25.23 sec; Iteration 6511 / 16000) loss: 1.383172
# (Time 25.27 sec; Iteration 6521 / 16000) loss: 1.226752
# (Time 25.30 sec; Iteration 6531 / 16000) loss: 1.318061
# (Time 25.34 sec; Iteration 6541 / 16000) loss: 1.479692
# (Time 25.38 sec; Iteration 6551 / 16000) loss: 1.322313
# (Time 25.40 sec; Iteration 6561 / 16000) loss: 1.341088
# (Time 25.44 sec; Iteration 6571 / 16000) loss: 1.075121
# (Time 25.48 sec; Iteration 6581 / 16000) loss: 1.220658
# (Time 25.51 sec; Iteration 6591 / 16000) loss: 1.332591
# (Time 25.55 sec; Iteration 6601 / 16000) loss: 1.484452
# (Time 25.59 sec; Iteration 6611 / 16000) loss: 1.531208
# (Time 25.62 sec; Iteration 6621 / 16000) loss: 1.282478
# (Time 25.66 sec; Iteration 6631 / 16000) loss: 1.108543
# (Time 25.70 sec; Iteration 6641 / 16000) loss: 1.293723
# (Time 25.73 sec; Iteration 6651 / 16000) loss: 1.433497
# (Time 25.77 sec; Iteration 6661 / 16000) loss: 1.296496
# (Time 25.80 sec; Iteration 6671 / 16000) loss: 1.417494
# (Time 25.84 sec; Iteration 6681 / 16000) loss: 1.415172
# (Time 25.87 sec; Iteration 6691 / 16000) loss: 1.222620
# (Time 25.91 sec; Iteration 6701 / 16000) loss: 1.182051
# (Time 25.94 sec; Iteration 6711 / 16000) loss: 1.337360
# (Time 25.98 sec; Iteration 6721 / 16000) loss: 1.134738
# (Time 26.02 sec; Iteration 6731 / 16000) loss: 1.363052
# (Time 26.05 sec; Iteration 6741 / 16000) loss: 1.380360
# (Time 26.09 sec; Iteration 6751 / 16000) loss: 1.481414
# (Time 26.12 sec; Iteration 6761 / 16000) loss: 1.499157
# (Time 26.15 sec; Iteration 6771 / 16000) loss: 1.285124
# (Time 26.19 sec; Iteration 6781 / 16000) loss: 1.120881
# (Time 26.23 sec; Iteration 6791 / 16000) loss: 1.278404
# (Time 26.26 sec; Iteration 6801 / 16000) loss: 1.489307
# (Time 26.30 sec; Iteration 6811 / 16000) loss: 1.163746
# (Time 26.33 sec; Iteration 6821 / 16000) loss: 1.372800
# (Time 26.37 sec; Iteration 6831 / 16000) loss: 1.387324
# (Time 26.40 sec; Iteration 6841 / 16000) loss: 1.346454
# (Time 26.44 sec; Iteration 6851 / 16000) loss: 1.387640
# (Time 26.48 sec; Iteration 6861 / 16000) loss: 1.251227
# (Time 26.51 sec; Iteration 6871 / 16000) loss: 1.388341
# (Time 26.55 sec; Iteration 6881 / 16000) loss: 1.253470
# (Time 26.59 sec; Iteration 6891 / 16000) loss: 1.328197
# (Time 26.63 sec; Iteration 6901 / 16000) loss: 1.514966
# (Time 26.66 sec; Iteration 6911 / 16000) loss: 1.298956
# (Time 26.70 sec; Iteration 6921 / 16000) loss: 1.137791
# (Time 26.73 sec; Iteration 6931 / 16000) loss: 1.273535
# (Time 26.77 sec; Iteration 6941 / 16000) loss: 1.381511
# (Time 26.81 sec; Iteration 6951 / 16000) loss: 1.398145
# (Time 26.84 sec; Iteration 6961 / 16000) loss: 1.407478
# (Time 26.88 sec; Iteration 6971 / 16000) loss: 1.362350
# (Time 26.92 sec; Iteration 6981 / 16000) loss: 1.496371
# (Time 26.95 sec; Iteration 6991 / 16000) loss: 1.210805
# (Time 26.99 sec; Iteration 7001 / 16000) loss: 1.397247
# (Time 27.03 sec; Iteration 7011 / 16000) loss: 1.475478
# (Time 27.06 sec; Iteration 7021 / 16000) loss: 1.279639
# (Time 27.10 sec; Iteration 7031 / 16000) loss: 1.351612
# (Time 27.14 sec; Iteration 7041 / 16000) loss: 1.280484
# (Time 27.18 sec; Iteration 7051 / 16000) loss: 1.245437
# (Time 27.21 sec; Iteration 7061 / 16000) loss: 1.154308
# (Time 27.25 sec; Iteration 7071 / 16000) loss: 1.488899
# (Time 27.28 sec; Iteration 7081 / 16000) loss: 1.230225
# (Time 27.32 sec; Iteration 7091 / 16000) loss: 1.217460
# (Time 27.36 sec; Iteration 7101 / 16000) loss: 1.565842
# (Time 27.39 sec; Iteration 7111 / 16000) loss: 1.515520
# (Time 27.43 sec; Iteration 7121 / 16000) loss: 1.201568
# (Time 27.46 sec; Iteration 7131 / 16000) loss: 1.511277
# (Time 27.50 sec; Iteration 7141 / 16000) loss: 1.255516
# (Time 27.54 sec; Iteration 7151 / 16000) loss: 1.447127
# (Time 27.57 sec; Iteration 7161 / 16000) loss: 1.352492
# (Time 27.61 sec; Iteration 7171 / 16000) loss: 1.177811
# (Time 27.64 sec; Iteration 7181 / 16000) loss: 1.178941
# (Time 27.68 sec; Iteration 7191 / 16000) loss: 1.322496
# (Epoch 9 / 20) train acc: 0.526000; val_acc: 0.491800
# (Time 27.89 sec; Iteration 7201 / 16000) loss: 1.393017
# (Time 27.93 sec; Iteration 7211 / 16000) loss: 1.058711
# (Time 27.97 sec; Iteration 7221 / 16000) loss: 1.202013
# (Time 28.00 sec; Iteration 7231 / 16000) loss: 1.234566
# (Time 28.04 sec; Iteration 7241 / 16000) loss: 1.386145
# (Time 28.07 sec; Iteration 7251 / 16000) loss: 1.349193
# (Time 28.11 sec; Iteration 7261 / 16000) loss: 1.533241
# (Time 28.15 sec; Iteration 7271 / 16000) loss: 1.206286
# (Time 28.18 sec; Iteration 7281 / 16000) loss: 1.277514
# (Time 28.22 sec; Iteration 7291 / 16000) loss: 1.437997
# (Time 28.25 sec; Iteration 7301 / 16000) loss: 1.393855
# (Time 28.29 sec; Iteration 7311 / 16000) loss: 1.494097
# (Time 28.33 sec; Iteration 7321 / 16000) loss: 1.195562
# (Time 28.36 sec; Iteration 7331 / 16000) loss: 1.470228
# (Time 28.40 sec; Iteration 7341 / 16000) loss: 1.281703
# (Time 28.43 sec; Iteration 7351 / 16000) loss: 1.097342
# (Time 28.47 sec; Iteration 7361 / 16000) loss: 1.536736
# (Time 28.50 sec; Iteration 7371 / 16000) loss: 1.568304
# (Time 28.54 sec; Iteration 7381 / 16000) loss: 1.379936
# (Time 28.57 sec; Iteration 7391 / 16000) loss: 1.128010
# (Time 28.61 sec; Iteration 7401 / 16000) loss: 1.254500
# (Time 28.65 sec; Iteration 7411 / 16000) loss: 1.153565
# (Time 28.68 sec; Iteration 7421 / 16000) loss: 1.183905
# (Time 28.72 sec; Iteration 7431 / 16000) loss: 1.453369
# (Time 28.75 sec; Iteration 7441 / 16000) loss: 1.246617
# (Time 28.79 sec; Iteration 7451 / 16000) loss: 1.599487
# (Time 28.83 sec; Iteration 7461 / 16000) loss: 1.227041
# (Time 28.86 sec; Iteration 7471 / 16000) loss: 1.409125
# (Time 28.90 sec; Iteration 7481 / 16000) loss: 1.405325
# (Time 28.94 sec; Iteration 7491 / 16000) loss: 1.156243
# (Time 28.97 sec; Iteration 7501 / 16000) loss: 1.105206
# (Time 29.00 sec; Iteration 7511 / 16000) loss: 1.269289
# (Time 29.04 sec; Iteration 7521 / 16000) loss: 1.111919
# (Time 29.08 sec; Iteration 7531 / 16000) loss: 1.340760
# (Time 29.12 sec; Iteration 7541 / 16000) loss: 1.285714
# (Time 29.15 sec; Iteration 7551 / 16000) loss: 1.458872
# (Time 29.19 sec; Iteration 7561 / 16000) loss: 1.353828
# (Time 29.23 sec; Iteration 7571 / 16000) loss: 1.516182
# (Time 29.26 sec; Iteration 7581 / 16000) loss: 1.131065
# (Time 29.30 sec; Iteration 7591 / 16000) loss: 1.320901
# (Time 29.33 sec; Iteration 7601 / 16000) loss: 1.485153
# (Time 29.37 sec; Iteration 7611 / 16000) loss: 1.241700
# (Time 29.40 sec; Iteration 7621 / 16000) loss: 1.447282
# (Time 29.44 sec; Iteration 7631 / 16000) loss: 1.559362
# (Time 29.48 sec; Iteration 7641 / 16000) loss: 1.092991
# (Time 29.51 sec; Iteration 7651 / 16000) loss: 1.514893
# (Time 29.55 sec; Iteration 7661 / 16000) loss: 1.140018
# (Time 29.58 sec; Iteration 7671 / 16000) loss: 1.138799
# (Time 29.61 sec; Iteration 7681 / 16000) loss: 1.444462
# (Time 29.65 sec; Iteration 7691 / 16000) loss: 1.060578
# (Time 29.69 sec; Iteration 7701 / 16000) loss: 1.319849
# (Time 29.72 sec; Iteration 7711 / 16000) loss: 1.359274
# (Time 29.76 sec; Iteration 7721 / 16000) loss: 1.442590
# (Time 29.80 sec; Iteration 7731 / 16000) loss: 1.343114
# (Time 29.83 sec; Iteration 7741 / 16000) loss: 1.308849
# (Time 29.86 sec; Iteration 7751 / 16000) loss: 1.190092
# (Time 29.90 sec; Iteration 7761 / 16000) loss: 1.305277
# (Time 29.94 sec; Iteration 7771 / 16000) loss: 1.358640
# (Time 29.98 sec; Iteration 7781 / 16000) loss: 1.542765
# (Time 30.01 sec; Iteration 7791 / 16000) loss: 1.180659
# (Time 30.05 sec; Iteration 7801 / 16000) loss: 1.382399
# (Time 30.09 sec; Iteration 7811 / 16000) loss: 1.296891
# (Time 30.12 sec; Iteration 7821 / 16000) loss: 1.316055
# (Time 30.15 sec; Iteration 7831 / 16000) loss: 1.329438
# (Time 30.19 sec; Iteration 7841 / 16000) loss: 1.205225
# (Time 30.23 sec; Iteration 7851 / 16000) loss: 1.361479
# (Time 30.27 sec; Iteration 7861 / 16000) loss: 1.295465
# (Time 30.30 sec; Iteration 7871 / 16000) loss: 1.158338
# (Time 30.34 sec; Iteration 7881 / 16000) loss: 1.446169
# (Time 30.37 sec; Iteration 7891 / 16000) loss: 1.567630
# (Time 30.41 sec; Iteration 7901 / 16000) loss: 1.444786
# (Time 30.45 sec; Iteration 7911 / 16000) loss: 1.428838
# (Time 30.48 sec; Iteration 7921 / 16000) loss: 1.310527
# (Time 30.52 sec; Iteration 7931 / 16000) loss: 1.538437
# (Time 30.56 sec; Iteration 7941 / 16000) loss: 1.407544
# (Time 30.59 sec; Iteration 7951 / 16000) loss: 1.414793
# (Time 30.62 sec; Iteration 7961 / 16000) loss: 1.422370
# (Time 30.66 sec; Iteration 7971 / 16000) loss: 1.349090
# (Time 30.70 sec; Iteration 7981 / 16000) loss: 1.063441
# (Time 30.73 sec; Iteration 7991 / 16000) loss: 1.080920
# (Epoch 10 / 20) train acc: 0.565000; val_acc: 0.494700
# (Time 30.94 sec; Iteration 8001 / 16000) loss: 1.332625
# (Time 30.98 sec; Iteration 8011 / 16000) loss: 1.197914
# (Time 31.01 sec; Iteration 8021 / 16000) loss: 1.271372
# (Time 31.05 sec; Iteration 8031 / 16000) loss: 1.311663
# (Time 31.09 sec; Iteration 8041 / 16000) loss: 1.389356
# (Time 31.12 sec; Iteration 8051 / 16000) loss: 1.412186
# (Time 31.16 sec; Iteration 8061 / 16000) loss: 1.353056
# (Time 31.19 sec; Iteration 8071 / 16000) loss: 1.290560
# (Time 31.23 sec; Iteration 8081 / 16000) loss: 1.211374
# (Time 31.26 sec; Iteration 8091 / 16000) loss: 1.229064
# (Time 31.30 sec; Iteration 8101 / 16000) loss: 1.367881
# (Time 31.33 sec; Iteration 8111 / 16000) loss: 1.066821
# (Time 31.37 sec; Iteration 8121 / 16000) loss: 1.358643
# (Time 31.41 sec; Iteration 8131 / 16000) loss: 1.250785
# (Time 31.44 sec; Iteration 8141 / 16000) loss: 1.425003
# (Time 31.48 sec; Iteration 8151 / 16000) loss: 1.133268
# (Time 31.51 sec; Iteration 8161 / 16000) loss: 1.312279
# (Time 31.55 sec; Iteration 8171 / 16000) loss: 1.527503
# (Time 31.59 sec; Iteration 8181 / 16000) loss: 1.336194
# (Time 31.62 sec; Iteration 8191 / 16000) loss: 1.350220
# (Time 31.66 sec; Iteration 8201 / 16000) loss: 1.498887
# (Time 31.69 sec; Iteration 8211 / 16000) loss: 1.267895
# (Time 31.73 sec; Iteration 8221 / 16000) loss: 1.456152
# (Time 31.77 sec; Iteration 8231 / 16000) loss: 1.439246
# (Time 31.80 sec; Iteration 8241 / 16000) loss: 1.699597
# (Time 31.84 sec; Iteration 8251 / 16000) loss: 1.450565
# (Time 31.88 sec; Iteration 8261 / 16000) loss: 1.228270
# (Time 31.91 sec; Iteration 8271 / 16000) loss: 1.207045
# (Time 31.95 sec; Iteration 8281 / 16000) loss: 1.051914
# (Time 31.98 sec; Iteration 8291 / 16000) loss: 1.104023
# (Time 32.02 sec; Iteration 8301 / 16000) loss: 1.285104
# (Time 32.05 sec; Iteration 8311 / 16000) loss: 1.275738
# (Time 32.09 sec; Iteration 8321 / 16000) loss: 1.435323
# (Time 32.12 sec; Iteration 8331 / 16000) loss: 1.380809
# (Time 32.16 sec; Iteration 8341 / 16000) loss: 1.291709
# (Time 32.20 sec; Iteration 8351 / 16000) loss: 1.034286
# (Time 32.23 sec; Iteration 8361 / 16000) loss: 1.308531
# (Time 32.27 sec; Iteration 8371 / 16000) loss: 1.576081
# (Time 32.30 sec; Iteration 8381 / 16000) loss: 1.024660
# (Time 32.34 sec; Iteration 8391 / 16000) loss: 1.137844
# (Time 32.37 sec; Iteration 8401 / 16000) loss: 1.243603
# (Time 32.41 sec; Iteration 8411 / 16000) loss: 1.271868
# (Time 32.45 sec; Iteration 8421 / 16000) loss: 1.089644
# (Time 32.48 sec; Iteration 8431 / 16000) loss: 1.173733
# (Time 32.52 sec; Iteration 8441 / 16000) loss: 1.091670
# (Time 32.56 sec; Iteration 8451 / 16000) loss: 1.162348
# (Time 32.60 sec; Iteration 8461 / 16000) loss: 1.287660
# (Time 32.64 sec; Iteration 8471 / 16000) loss: 1.396924
# (Time 32.67 sec; Iteration 8481 / 16000) loss: 1.268259
# (Time 32.70 sec; Iteration 8491 / 16000) loss: 1.379399
# (Time 32.74 sec; Iteration 8501 / 16000) loss: 1.086658
# (Time 32.78 sec; Iteration 8511 / 16000) loss: 1.176955
# ...
# (Time 50.69 sec; Iteration 13241 / 16000) loss: 0.931225
# (Time 50.73 sec; Iteration 13251 / 16000) loss: 1.181263
# (Time 50.76 sec; Iteration 13261 / 16000) loss: 1.259763
# (Time 50.80 sec; Iteration 13271 / 16000) loss: 1.072144
# (Time 50.83 sec; Iteration 13281 / 16000) loss: 1.209577
# (Time 50.86 sec; Iteration 13291 / 16000) loss: 1.107164
# (Time 50.90 sec; Iteration 13301 / 16000) loss: 1.086489
# (Time 50.94 sec; Iteration 13311 / 16000) loss: 1.000543
# (Time 50.97 sec; Iteration 13321 / 16000) loss: 1.032668
# (Time 51.00 sec; Iteration 13331 / 16000) loss: 1.172641
# (Time 51.04 sec; Iteration 13341 / 16000) loss: 1.179451
# (Time 51.08 sec; Iteration 13351 / 16000) loss: 1.381614
# (Time 51.11 sec; Iteration 13361 / 16000) loss: 1.159373
# (Time 51.15 sec; Iteration 13371 / 16000) loss: 0.957894
# (Time 51.18 sec; Iteration 13381 / 16000) loss: 1.456787
# (Time 51.22 sec; Iteration 13391 / 16000) loss: 1.180222
# (Time 51.25 sec; Iteration 13401 / 16000) loss: 1.029274
# (Time 51.29 sec; Iteration 13411 / 16000) loss: 1.087175
# (Time 51.33 sec; Iteration 13421 / 16000) loss: 1.319461
# (Time 51.36 sec; Iteration 13431 / 16000) loss: 1.199254
# (Time 51.40 sec; Iteration 13441 / 16000) loss: 0.944556
# (Time 51.43 sec; Iteration 13451 / 16000) loss: 1.312802
# (Time 51.46 sec; Iteration 13461 / 16000) loss: 1.074899
# (Time 51.50 sec; Iteration 13471 / 16000) loss: 1.081910
# (Time 51.53 sec; Iteration 13481 / 16000) loss: 1.178751
# (Time 51.57 sec; Iteration 13491 / 16000) loss: 1.160814
# (Time 51.61 sec; Iteration 13501 / 16000) loss: 1.086706
# (Time 51.64 sec; Iteration 13511 / 16000) loss: 1.267531
# (Time 51.68 sec; Iteration 13521 / 16000) loss: 1.076104
# (Time 51.72 sec; Iteration 13531 / 16000) loss: 1.337711
# (Time 51.75 sec; Iteration 13541 / 16000) loss: 0.993889
# (Time 51.79 sec; Iteration 13551 / 16000) loss: 1.298326
# (Time 51.82 sec; Iteration 13561 / 16000) loss: 1.147583
# (Time 51.86 sec; Iteration 13571 / 16000) loss: 1.078720
# (Time 51.89 sec; Iteration 13581 / 16000) loss: 0.984018
# (Time 51.93 sec; Iteration 13591 / 16000) loss: 1.053999
# (Epoch 17 / 20) train acc: 0.613000; val_acc: 0.521300
# (Time 52.14 sec; Iteration 13601 / 16000) loss: 1.165740
# (Time 52.17 sec; Iteration 13611 / 16000) loss: 1.343992
# (Time 52.20 sec; Iteration 13621 / 16000) loss: 1.133359
# (Time 52.24 sec; Iteration 13631 / 16000) loss: 1.565534
# (Time 52.28 sec; Iteration 13641 / 16000) loss: 1.138264
# (Time 52.31 sec; Iteration 13651 / 16000) loss: 1.195034
# (Time 52.34 sec; Iteration 13661 / 16000) loss: 0.819719
# (Time 52.39 sec; Iteration 13671 / 16000) loss: 0.863959
# (Time 52.43 sec; Iteration 13681 / 16000) loss: 1.186231
# (Time 52.46 sec; Iteration 13691 / 16000) loss: 1.080374
# (Time 52.50 sec; Iteration 13701 / 16000) loss: 1.052009
# (Time 52.53 sec; Iteration 13711 / 16000) loss: 1.466456
# (Time 52.57 sec; Iteration 13721 / 16000) loss: 1.347416
# (Time 52.61 sec; Iteration 13731 / 16000) loss: 1.323484
# (Time 52.64 sec; Iteration 13741 / 16000) loss: 1.011968
# (Time 52.68 sec; Iteration 13751 / 16000) loss: 1.373813
# (Time 52.72 sec; Iteration 13761 / 16000) loss: 1.077482
# (Time 52.75 sec; Iteration 13771 / 16000) loss: 1.269137
# (Time 52.79 sec; Iteration 13781 / 16000) loss: 0.932443
# (Time 52.82 sec; Iteration 13791 / 16000) loss: 1.247616
# (Time 52.86 sec; Iteration 13801 / 16000) loss: 1.024042
# (Time 52.89 sec; Iteration 13811 / 16000) loss: 1.074065
# (Time 52.93 sec; Iteration 13821 / 16000) loss: 1.107951
# (Time 52.96 sec; Iteration 13831 / 16000) loss: 1.209588
# (Time 53.00 sec; Iteration 13841 / 16000) loss: 1.213944
# (Time 53.03 sec; Iteration 13851 / 16000) loss: 1.567835
# (Time 53.07 sec; Iteration 13861 / 16000) loss: 1.100776
# (Time 53.10 sec; Iteration 13871 / 16000) loss: 0.997358
# (Time 53.14 sec; Iteration 13881 / 16000) loss: 0.951060
# (Time 53.18 sec; Iteration 13891 / 16000) loss: 0.997292
# (Time 53.21 sec; Iteration 13901 / 16000) loss: 1.031950
# (Time 53.25 sec; Iteration 13911 / 16000) loss: 1.043939
# (Time 53.28 sec; Iteration 13921 / 16000) loss: 1.084389
# (Time 53.32 sec; Iteration 13931 / 16000) loss: 0.842245
# (Time 53.35 sec; Iteration 13941 / 16000) loss: 0.924738
# (Time 53.39 sec; Iteration 13951 / 16000) loss: 0.925270
# (Time 53.43 sec; Iteration 13961 / 16000) loss: 0.905140
# (Time 53.46 sec; Iteration 13971 / 16000) loss: 1.196813
# (Time 53.50 sec; Iteration 13981 / 16000) loss: 1.034290
# (Time 53.53 sec; Iteration 13991 / 16000) loss: 1.017996
# (Time 53.57 sec; Iteration 14001 / 16000) loss: 1.227669
# (Time 53.60 sec; Iteration 14011 / 16000) loss: 1.031123
# (Time 53.64 sec; Iteration 14021 / 16000) loss: 1.201904
# (Time 53.67 sec; Iteration 14031 / 16000) loss: 1.084917
# (Time 53.70 sec; Iteration 14041 / 16000) loss: 1.327901
# (Time 53.75 sec; Iteration 14051 / 16000) loss: 1.178550
# (Time 53.78 sec; Iteration 14061 / 16000) loss: 1.342887
# (Time 53.82 sec; Iteration 14071 / 16000) loss: 1.149066
# (Time 53.86 sec; Iteration 14081 / 16000) loss: 1.185654
# (Time 53.89 sec; Iteration 14091 / 16000) loss: 1.019414
# (Time 53.93 sec; Iteration 14101 / 16000) loss: 1.034757
# (Time 53.96 sec; Iteration 14111 / 16000) loss: 1.341699
# (Time 54.00 sec; Iteration 14121 / 16000) loss: 1.039860
# (Time 54.03 sec; Iteration 14131 / 16000) loss: 1.173634
# (Time 54.07 sec; Iteration 14141 / 16000) loss: 1.054382
# (Time 54.11 sec; Iteration 14151 / 16000) loss: 1.133164
# (Time 54.14 sec; Iteration 14161 / 16000) loss: 1.096411
# (Time 54.18 sec; Iteration 14171 / 16000) loss: 1.241139
# (Time 54.21 sec; Iteration 14181 / 16000) loss: 1.358652
# (Time 54.25 sec; Iteration 14191 / 16000) loss: 1.164932
# (Time 54.28 sec; Iteration 14201 / 16000) loss: 1.385160
# (Time 54.32 sec; Iteration 14211 / 16000) loss: 1.119275
# (Time 54.35 sec; Iteration 14221 / 16000) loss: 1.355106
# (Time 54.39 sec; Iteration 14231 / 16000) loss: 1.124088
# (Time 54.42 sec; Iteration 14241 / 16000) loss: 1.112293
# (Time 54.45 sec; Iteration 14251 / 16000) loss: 1.014244
# (Time 54.49 sec; Iteration 14261 / 16000) loss: 1.106376
# (Time 54.53 sec; Iteration 14271 / 16000) loss: 1.159410
# (Time 54.57 sec; Iteration 14281 / 16000) loss: 0.957465
# (Time 54.60 sec; Iteration 14291 / 16000) loss: 1.161128
# (Time 54.64 sec; Iteration 14301 / 16000) loss: 1.001007
# (Time 54.67 sec; Iteration 14311 / 16000) loss: 1.013973
# (Time 54.71 sec; Iteration 14321 / 16000) loss: 1.056254
# (Time 54.74 sec; Iteration 14331 / 16000) loss: 0.801591
# (Time 54.78 sec; Iteration 14341 / 16000) loss: 1.009905
# (Time 54.81 sec; Iteration 14351 / 16000) loss: 1.236106
# (Time 54.85 sec; Iteration 14361 / 16000) loss: 1.061351
# (Time 54.89 sec; Iteration 14371 / 16000) loss: 1.121881
# (Time 54.92 sec; Iteration 14381 / 16000) loss: 1.001688
# (Time 54.95 sec; Iteration 14391 / 16000) loss: 0.808369
# (Epoch 18 / 20) train acc: 0.622000; val_acc: 0.525900
# (Time 55.16 sec; Iteration 14401 / 16000) loss: 0.959128
# (Time 55.20 sec; Iteration 14411 / 16000) loss: 1.120066
# (Time 55.24 sec; Iteration 14421 / 16000) loss: 1.051220
# (Time 55.28 sec; Iteration 14431 / 16000) loss: 1.021109
# (Time 55.31 sec; Iteration 14441 / 16000) loss: 0.967266
# (Time 55.35 sec; Iteration 14451 / 16000) loss: 1.034396
# (Time 55.39 sec; Iteration 14461 / 16000) loss: 1.058179
# (Time 55.42 sec; Iteration 14471 / 16000) loss: 1.179957
# (Time 55.45 sec; Iteration 14481 / 16000) loss: 1.032712
# (Time 55.49 sec; Iteration 14491 / 16000) loss: 1.128021
# (Time 55.52 sec; Iteration 14501 / 16000) loss: 0.978145
# (Time 55.56 sec; Iteration 14511 / 16000) loss: 0.884451
# (Time 55.60 sec; Iteration 14521 / 16000) loss: 0.996395
# (Time 55.63 sec; Iteration 14531 / 16000) loss: 1.025198
# (Time 55.67 sec; Iteration 14541 / 16000) loss: 1.094517
# (Time 55.70 sec; Iteration 14551 / 16000) loss: 1.245659
# (Time 55.74 sec; Iteration 14561 / 16000) loss: 1.128911
# (Time 55.77 sec; Iteration 14571 / 16000) loss: 0.980341
# (Time 55.81 sec; Iteration 14581 / 16000) loss: 1.076175
# (Time 55.84 sec; Iteration 14591 / 16000) loss: 1.163336
# (Time 55.88 sec; Iteration 14601 / 16000) loss: 1.001102
# (Time 55.91 sec; Iteration 14611 / 16000) loss: 1.215285
# (Time 55.95 sec; Iteration 14621 / 16000) loss: 0.798160
# (Time 55.98 sec; Iteration 14631 / 16000) loss: 1.422536
# (Time 56.02 sec; Iteration 14641 / 16000) loss: 1.119300
# (Time 56.05 sec; Iteration 14651 / 16000) loss: 0.930839
# (Time 56.09 sec; Iteration 14661 / 16000) loss: 0.991283
# (Time 56.13 sec; Iteration 14671 / 16000) loss: 0.989937
# (Time 56.16 sec; Iteration 14681 / 16000) loss: 1.081188
# (Time 56.20 sec; Iteration 14691 / 16000) loss: 1.260976
# (Time 56.23 sec; Iteration 14701 / 16000) loss: 1.464604
# (Time 56.27 sec; Iteration 14711 / 16000) loss: 0.980722
# (Time 56.30 sec; Iteration 14721 / 16000) loss: 0.864899
# (Time 56.34 sec; Iteration 14731 / 16000) loss: 0.827623
# (Time 56.38 sec; Iteration 14741 / 16000) loss: 0.976056
# (Time 56.41 sec; Iteration 14751 / 16000) loss: 0.957298
# (Time 56.45 sec; Iteration 14761 / 16000) loss: 1.181737
# (Time 56.48 sec; Iteration 14771 / 16000) loss: 1.031237
# (Time 56.52 sec; Iteration 14781 / 16000) loss: 1.041961
# (Time 56.55 sec; Iteration 14791 / 16000) loss: 0.935345
# (Time 56.59 sec; Iteration 14801 / 16000) loss: 1.024610
# (Time 56.63 sec; Iteration 14811 / 16000) loss: 1.000000
# (Time 56.66 sec; Iteration 14821 / 16000) loss: 1.078645
# (Time 56.70 sec; Iteration 14831 / 16000) loss: 1.203873
# (Time 56.74 sec; Iteration 14841 / 16000) loss: 1.213101
# (Time 56.78 sec; Iteration 14851 / 16000) loss: 1.040644
# (Time 56.81 sec; Iteration 14861 / 16000) loss: 1.336032
# (Time 56.84 sec; Iteration 14871 / 16000) loss: 0.876064
# (Time 56.88 sec; Iteration 14881 / 16000) loss: 0.907616
# (Time 56.91 sec; Iteration 14891 / 16000) loss: 1.145075
# (Time 56.95 sec; Iteration 14901 / 16000) loss: 1.145000
# (Time 56.98 sec; Iteration 14911 / 16000) loss: 1.099613
# (Time 57.02 sec; Iteration 14921 / 16000) loss: 1.124845
# (Time 57.05 sec; Iteration 14931 / 16000) loss: 0.931014
# (Time 57.09 sec; Iteration 14941 / 16000) loss: 1.089419
# (Time 57.12 sec; Iteration 14951 / 16000) loss: 1.112443
# (Time 57.15 sec; Iteration 14961 / 16000) loss: 0.885799
# (Time 57.20 sec; Iteration 14971 / 16000) loss: 1.266925
# (Time 57.23 sec; Iteration 14981 / 16000) loss: 0.963372
# (Time 57.27 sec; Iteration 14991 / 16000) loss: 1.118968
# (Time 57.30 sec; Iteration 15001 / 16000) loss: 1.125165
# (Time 57.34 sec; Iteration 15011 / 16000) loss: 1.353623
# (Time 57.37 sec; Iteration 15021 / 16000) loss: 1.071930
# (Time 57.40 sec; Iteration 15031 / 16000) loss: 1.068922
# (Time 57.45 sec; Iteration 15041 / 16000) loss: 1.045403
# (Time 57.48 sec; Iteration 15051 / 16000) loss: 1.352881
# (Time 57.52 sec; Iteration 15061 / 16000) loss: 1.199840
# (Time 57.55 sec; Iteration 15071 / 16000) loss: 1.119933
# (Time 57.59 sec; Iteration 15081 / 16000) loss: 0.975014
# (Time 57.63 sec; Iteration 15091 / 16000) loss: 0.967085
# (Time 57.66 sec; Iteration 15101 / 16000) loss: 1.104508
# (Time 57.70 sec; Iteration 15111 / 16000) loss: 0.824036
# (Time 57.73 sec; Iteration 15121 / 16000) loss: 1.227272
# (Time 57.77 sec; Iteration 15131 / 16000) loss: 1.069889
# (Time 57.81 sec; Iteration 15141 / 16000) loss: 0.865343
# (Time 57.84 sec; Iteration 15151 / 16000) loss: 1.163137
# (Time 57.88 sec; Iteration 15161 / 16000) loss: 1.114158
# (Time 57.91 sec; Iteration 15171 / 16000) loss: 1.346093
# (Time 57.95 sec; Iteration 15181 / 16000) loss: 1.152251
# (Time 57.98 sec; Iteration 15191 / 16000) loss: 0.829013
# (Epoch 19 / 20) train acc: 0.616000; val_acc: 0.522700
# (Time 58.20 sec; Iteration 15201 / 16000) loss: 0.962834
# (Time 58.23 sec; Iteration 15211 / 16000) loss: 0.948436
# (Time 58.27 sec; Iteration 15221 / 16000) loss: 0.868542
# (Time 58.30 sec; Iteration 15231 / 16000) loss: 0.971393
# (Time 58.34 sec; Iteration 15241 / 16000) loss: 0.945033
# (Time 58.38 sec; Iteration 15251 / 16000) loss: 1.310324
# (Time 58.41 sec; Iteration 15261 / 16000) loss: 1.254422
# (Time 58.45 sec; Iteration 15271 / 16000) loss: 1.115593
# (Time 58.48 sec; Iteration 15281 / 16000) loss: 1.176797
# (Time 58.52 sec; Iteration 15291 / 16000) loss: 1.142439
# (Time 58.55 sec; Iteration 15301 / 16000) loss: 1.013978
# (Time 58.59 sec; Iteration 15311 / 16000) loss: 0.982845
# (Time 58.62 sec; Iteration 15321 / 16000) loss: 1.099602
# (Time 58.65 sec; Iteration 15331 / 16000) loss: 1.166233
# (Time 58.69 sec; Iteration 15341 / 16000) loss: 1.023656
# (Time 58.73 sec; Iteration 15351 / 16000) loss: 1.056099
# (Time 58.76 sec; Iteration 15361 / 16000) loss: 1.203640
# (Time 58.80 sec; Iteration 15371 / 16000) loss: 0.881681
# (Time 58.83 sec; Iteration 15381 / 16000) loss: 0.921093
# (Time 58.87 sec; Iteration 15391 / 16000) loss: 0.921297
# (Time 58.90 sec; Iteration 15401 / 16000) loss: 0.964611
# (Time 58.94 sec; Iteration 15411 / 16000) loss: 1.165792
# (Time 58.98 sec; Iteration 15421 / 16000) loss: 1.218526
# (Time 59.01 sec; Iteration 15431 / 16000) loss: 1.044211
# (Time 59.04 sec; Iteration 15441 / 16000) loss: 0.952570
# (Time 59.08 sec; Iteration 15451 / 16000) loss: 0.994072
# (Time 59.12 sec; Iteration 15461 / 16000) loss: 1.179397
# (Time 59.15 sec; Iteration 15471 / 16000) loss: 0.876458
# (Time 59.19 sec; Iteration 15481 / 16000) loss: 0.881562
# (Time 59.22 sec; Iteration 15491 / 16000) loss: 1.031049
# (Time 59.26 sec; Iteration 15501 / 16000) loss: 0.941970
# (Time 59.30 sec; Iteration 15511 / 16000) loss: 1.000565
# (Time 59.34 sec; Iteration 15521 / 16000) loss: 1.008798
# (Time 59.37 sec; Iteration 15531 / 16000) loss: 1.044504
# (Time 59.40 sec; Iteration 15541 / 16000) loss: 1.164681
# (Time 59.44 sec; Iteration 15551 / 16000) loss: 0.845637
# (Time 59.47 sec; Iteration 15561 / 16000) loss: 1.109355
# (Time 59.51 sec; Iteration 15571 / 16000) loss: 1.195163
# (Time 59.55 sec; Iteration 15581 / 16000) loss: 0.800471
# (Time 59.58 sec; Iteration 15591 / 16000) loss: 1.192396
# (Time 59.62 sec; Iteration 15601 / 16000) loss: 1.133184
# (Time 59.65 sec; Iteration 15611 / 16000) loss: 0.867477
# (Time 59.69 sec; Iteration 15621 / 16000) loss: 1.056579
# (Time 59.73 sec; Iteration 15631 / 16000) loss: 1.033238
# (Time 59.76 sec; Iteration 15641 / 16000) loss: 0.927837
# (Time 59.80 sec; Iteration 15651 / 16000) loss: 0.914094
# (Time 59.83 sec; Iteration 15661 / 16000) loss: 0.989009
# (Time 59.87 sec; Iteration 15671 / 16000) loss: 1.139400
# (Time 59.90 sec; Iteration 15681 / 16000) loss: 1.151457
# (Time 59.94 sec; Iteration 15691 / 16000) loss: 1.091607
# (Time 59.97 sec; Iteration 15701 / 16000) loss: 1.124505
# (Time 60.01 sec; Iteration 15711 / 16000) loss: 1.029417
# (Time 60.04 sec; Iteration 15721 / 16000) loss: 1.019237
# (Time 60.08 sec; Iteration 15731 / 16000) loss: 0.955645
# (Time 60.12 sec; Iteration 15741 / 16000) loss: 0.886979
# (Time 60.15 sec; Iteration 15751 / 16000) loss: 1.069038
# (Time 60.18 sec; Iteration 15761 / 16000) loss: 0.985783
# (Time 60.22 sec; Iteration 15771 / 16000) loss: 1.156264
# (Time 60.25 sec; Iteration 15781 / 16000) loss: 0.842785
# (Time 60.29 sec; Iteration 15791 / 16000) loss: 1.094943
# (Time 60.33 sec; Iteration 15801 / 16000) loss: 0.977431
# (Time 60.36 sec; Iteration 15811 / 16000) loss: 1.071636
# (Time 60.40 sec; Iteration 15821 / 16000) loss: 0.947569
# (Time 60.44 sec; Iteration 15831 / 16000) loss: 0.929155
# (Time 60.47 sec; Iteration 15841 / 16000) loss: 1.109881
# (Time 60.51 sec; Iteration 15851 / 16000) loss: 1.132118
# (Time 60.55 sec; Iteration 15861 / 16000) loss: 1.082940
# (Time 60.59 sec; Iteration 15871 / 16000) loss: 0.987208
# (Time 60.62 sec; Iteration 15881 / 16000) loss: 0.950660
# (Time 60.65 sec; Iteration 15891 / 16000) loss: 0.986380
# (Time 60.69 sec; Iteration 15901 / 16000) loss: 1.348951
# (Time 60.73 sec; Iteration 15911 / 16000) loss: 0.980402
# (Time 60.76 sec; Iteration 15921 / 16000) loss: 1.015270
# (Time 60.80 sec; Iteration 15931 / 16000) loss: 0.895316
# (Time 60.83 sec; Iteration 15941 / 16000) loss: 1.135472
# (Time 60.87 sec; Iteration 15951 / 16000) loss: 0.965072
# (Time 60.90 sec; Iteration 15961 / 16000) loss: 1.058417
# (Time 60.94 sec; Iteration 15971 / 16000) loss: 0.805680
# (Time 60.98 sec; Iteration 15981 / 16000) loss: 0.820627
# (Time 61.02 sec; Iteration 15991 / 16000) loss: 0.872988
# (Epoch 20 / 20) train acc: 0.641000; val_acc: 0.531900

# %%
# Run this cell to visualize training loss and train / val accuracy
plt.subplot(2, 1, 1)
plt.title('Training loss')
plt.plot(solver.loss_history, 'o')
plt.xlabel('Iteration')

plt.subplot(2, 1, 2)
plt.title('Accuracy')
plt.plot(solver.train_acc_history, '-o', label='train')
plt.plot(solver.val_acc_history, '-o', label='val')
plt.plot([0.5] * len(solver.val_acc_history), 'k--')
plt.xlabel('Epoch')
plt.legend(loc='lower right')
plt.gcf().set_size_inches(15, 12)
plt.show()

# %% [markdown]
# If you're happy with the model's perfromance, run the following cell to save it.
#
# We will also reload the model and run it on validation to verify it's the right weights.

# %%
import os

local_path = '.'
path = os.path.join(local_path, 'best_two_layer_net.pth')
solver.model.save(path)

# Create a new instance
from fully_connected_networks import create_solver_instance
reset_seed(0)

solver = create_solver_instance(data_dict=data_dict, dtype=torch.float64, device=device)

# Load model
solver.model.load(path, dtype=torch.float64, device=device)

# Evaluate on validation set
accuracy = solver.check_accuracy(solver.X_val, solver.y_val)
print(f"Saved model's accuracy on validation is {accuracy}")
# Out:
# Saved in .\best_two_layer_net.pth
# load checkpoint file: .\best_two_layer_net.pth
# Saved model's accuracy on validation is 0.5318999886512756

# %% [markdown]
# # Multilayer network
# Next you will implement a fully-connected network with an arbitrary number of hidden layers.
#
# Read through the `FullyConnectedNet` class in `fully_connected_networks.py`. Implement the initialization, the forward pass, and the backward pass. For the moment don't worry about implementing dropout; we will add this feature soon.

# %% [markdown]
# ## Initial loss and gradient check
#
# As a sanity check, run the following to check the initial loss and to gradient check the network both with and without regularization. Do the initial losses seem reasonable?
#
# For gradient checking, you should expect to see errors less than `1e-6`, except for the check on `W1` and `W2` with `reg=0` where your errors should be less than `1e-5`.

# %%
from fully_connected_networks import FullyConnectedNet

reset_seed(0)
N, D, H1, H2, C = 2, 15, 20, 30, 10
X = torch.randn(N, D, dtype=torch.float64, device=device)
y = torch.randint(C, size=(N,), dtype=torch.int64, device=device)

for reg in [0, 3.14]:
  print('Running check with reg = ', reg)
  model = FullyConnectedNet(
        [H1, H2], 
        input_dim=D,
        num_classes=C,
        reg=reg,
        weight_scale=5e-2, 
        dtype=torch.float64, 
        device=device
  )

  loss, grads = model.loss(X, y)
  print('Initial loss: ', loss.item())

  for name in sorted(grads):
    f = lambda _: model.loss(X, y)[0]
    grad_num = libs.grad.compute_numeric_gradient(f, model.params[name])
    print('%s relative error: %.2e' % (name, libs.grad.rel_error(grad_num, grads[name])))
# Out:
# Running check with reg =  0
# Initial loss:  2.3053575717037686
# W1 relative error: 5.28e-08
# W2 relative error: 8.33e-08
# W3 relative error: 4.64e-08
# b1 relative error: 1.28e-07
# b2 relative error: 1.83e-08
# b3 relative error: 2.57e-09
# Running check with reg =  3.14
# Initial loss:  7.29369633719099
# W1 relative error: 6.79e-09
# W2 relative error: 8.39e-09
# W3 relative error: 9.56e-09
# b1 relative error: 1.25e-07
# b2 relative error: 2.91e-08
# b3 relative error: 6.23e-09

# %% [markdown]
# As another sanity check, make sure you can overfit a small dataset of 50 images. First we will try a three-layer network with 100 units in each hidden layer. In the following cell, tweak the **learning rate** and **weight initialization scale** to overfit and achieve 100% training accuracy within 20 epochs.

# %%
from fully_connected_networks import FullyConnectedNet, get_three_layer_network_params


reset_seed(0)

num_train = 50
small_data = {
  'X_train': data_dict['X_train'][:num_train],
  'y_train': data_dict['y_train'][:num_train],
  'X_val': data_dict['X_val'],
  'y_val': data_dict['y_val'],
}

# Update parameters in get_three_layer_network_params
weight_scale, learning_rate = get_three_layer_network_params()

weight_scale = 0.05
learning_rate = 1
model = FullyConnectedNet([100, 100],
                weight_scale=weight_scale, dtype=torch.float32, device=device)
solver = Solver(model, small_data,
                  print_every=10, num_epochs=20, batch_size=25,
                  optim_config={
                    'learning_rate': learning_rate,
                  },
                  device=device
          )
solver.train()

plt.plot(solver.loss_history, 'o')
plt.title('Training loss history')
plt.xlabel('Iteration')
plt.ylabel('Training loss')
plt.show()
# Out:
# (Time 0.00 sec; Iteration 1 / 40) loss: 2.359247
# (Epoch 0 / 20) train acc: 0.160000; val_acc: 0.101600
# (Epoch 1 / 20) train acc: 0.240000; val_acc: 0.101600
# (Epoch 2 / 20) train acc: 0.440000; val_acc: 0.142100
# (Epoch 3 / 20) train acc: 0.380000; val_acc: 0.126000
# (Epoch 4 / 20) train acc: 0.640000; val_acc: 0.168500
# (Epoch 5 / 20) train acc: 0.560000; val_acc: 0.152900
# (Time 0.27 sec; Iteration 11 / 40) loss: 1.028444
# (Epoch 6 / 20) train acc: 0.460000; val_acc: 0.137000
# (Epoch 7 / 20) train acc: 0.460000; val_acc: 0.128100
# (Epoch 8 / 20) train acc: 0.580000; val_acc: 0.123800
# (Epoch 9 / 20) train acc: 0.680000; val_acc: 0.142200
# (Epoch 10 / 20) train acc: 0.640000; val_acc: 0.170200
# (Time 0.38 sec; Iteration 21 / 40) loss: 1.175406
# (Epoch 11 / 20) train acc: 0.840000; val_acc: 0.157700
# (Epoch 12 / 20) train acc: 0.780000; val_acc: 0.137600
# (Epoch 13 / 20) train acc: 0.820000; val_acc: 0.173600
# (Epoch 14 / 20) train acc: 0.960000; val_acc: 0.183100
# (Epoch 15 / 20) train acc: 0.880000; val_acc: 0.169100
# (Time 0.50 sec; Iteration 31 / 40) loss: 0.451672
# (Epoch 16 / 20) train acc: 0.920000; val_acc: 0.150900
# (Epoch 17 / 20) train acc: 0.960000; val_acc: 0.168000
# (Epoch 18 / 20) train acc: 0.980000; val_acc: 0.177500
# (Epoch 19 / 20) train acc: 0.980000; val_acc: 0.171900
# (Epoch 20 / 20) train acc: 1.000000; val_acc: 0.178600

# %% [markdown]
# Now try to use a five-layer network with 100 units on each layer to overfit 50 training examples. Again, you will have to adjust the learning rate and weight initialization scale, but you should be able to achieve 100% training accuracy.

# %%
from fully_connected_networks import FullyConnectedNet, get_five_layer_network_params


reset_seed(0)

num_train = 50
small_data = {
  'X_train': data_dict['X_train'][:num_train],
  'y_train': data_dict['y_train'][:num_train],
  'X_val': data_dict['X_val'],
  'y_val': data_dict['y_val'],
}


# Update parameters in get_three_layer_network_params
weight_scale, learning_rate = get_five_layer_network_params()
weight_scale = 0.08
learning_rate = 0.5
# Run models and solver with parameters
model = FullyConnectedNet([100, 100, 100, 100],
                weight_scale=weight_scale, dtype=torch.float32, device=device)
solver = Solver(model, small_data,
                print_every=10, num_epochs=20, batch_size=25,
                optim_config={
                  'learning_rate': learning_rate,
                },
                device=device,
         )
# Turn off keep_best_params to allow final weights to be saved, instead of best weights on validation set.
solver.train(return_best_params=False)

plt.plot(solver.loss_history, 'o')
plt.title('Training loss history')
plt.xlabel('Iteration')
plt.ylabel('Training loss')
plt.show()
# Out:
# (Time 0.01 sec; Iteration 1 / 40) loss: 2.294877
# (Epoch 0 / 20) train acc: 0.160000; val_acc: 0.101600
# (Epoch 1 / 20) train acc: 0.200000; val_acc: 0.105400
# (Epoch 2 / 20) train acc: 0.260000; val_acc: 0.115400
# (Epoch 3 / 20) train acc: 0.380000; val_acc: 0.122100
# (Epoch 4 / 20) train acc: 0.380000; val_acc: 0.160700
# (Epoch 5 / 20) train acc: 0.440000; val_acc: 0.138000
# (Time 0.47 sec; Iteration 11 / 40) loss: 1.440280
# (Epoch 6 / 20) train acc: 0.340000; val_acc: 0.120800
# (Epoch 7 / 20) train acc: 0.520000; val_acc: 0.141500
# (Epoch 8 / 20) train acc: 0.580000; val_acc: 0.178500
# (Epoch 9 / 20) train acc: 0.640000; val_acc: 0.174100
# (Epoch 10 / 20) train acc: 0.520000; val_acc: 0.161000
# (Time 0.65 sec; Iteration 21 / 40) loss: 1.289582
# (Epoch 11 / 20) train acc: 0.700000; val_acc: 0.166700
# (Epoch 12 / 20) train acc: 0.680000; val_acc: 0.179200
# (Epoch 13 / 20) train acc: 0.740000; val_acc: 0.175200
# (Epoch 14 / 20) train acc: 0.860000; val_acc: 0.192900
# (Epoch 15 / 20) train acc: 0.900000; val_acc: 0.187500
# (Time 0.82 sec; Iteration 31 / 40) loss: 0.406677
# (Epoch 16 / 20) train acc: 0.980000; val_acc: 0.187700
# (Epoch 17 / 20) train acc: 0.980000; val_acc: 0.195500
# (Epoch 18 / 20) train acc: 0.980000; val_acc: 0.197200
# (Epoch 19 / 20) train acc: 1.000000; val_acc: 0.193600
# (Epoch 20 / 20) train acc: 1.000000; val_acc: 0.196600

# %% [markdown]
# If you're satisfied with your model's performance, save the overfit model. Just a sanity check, we evaluate it one the training set again to verify that the saved weights have the correct performance.

# %%
import os

local_path = '.'
path = os.path.join(local_path, 'best_overfit_five_layer_net.pth')
solver.model.save(path)


# Create a new instance  -- Note that hidden dims being different doesn't matter here.
model = FullyConnectedNet(hidden_dims=[100, ], dtype=torch.float32, device=device)
solver = Solver(model, small_data,
                print_every=10, num_epochs=20, batch_size=25,
                optim_config={
                  'learning_rate': learning_rate,
                },
                device=device,
         )


# Load model
solver.model.load(path, dtype=torch.float32, device=device)

# Evaluate on validation set
accuracy = solver.check_accuracy(solver.X_train, solver.y_train)
print(f"Saved model's accuracy on small train is {accuracy}")
# Out:
# Saved in .\best_overfit_five_layer_net.pth
# load checkpoint file: .\best_overfit_five_layer_net.pth
# Saved model's accuracy on small train is 1.0

# %% [markdown]
# # Update rules
# So far we have used vanilla stochastic gradient descent (SGD) as our update rule. More sophisticated update rules can make it easier to train deep networks. We will implement a few of the most commonly used update rules and compare them to vanilla SGD.

# %% [markdown]
# ## SGD+Momentum
# Stochastic gradient descent with momentum is a widely used update rule that tends to make deep networks converge faster than vanilla stochastic gradient descent. See the Momentum Update section at http://cs231n.github.io/neural-networks-3/#sgd for more information.
#
# We will implement various first-order update rules that are commonly used
# for training neural networks. Each update rule accepts current weights and the
# gradient of the loss with respect to those weights and produces the next set of
# weights. Each update rule has the same interface:
# ```python
# def update(w, dw, config=None):
# Inputs:
#   - w: A tensor giving the current weights.
#   - dw: A tensor of the same shape as w giving the gradient of the
#     loss with respect to w.
#   - config: A dictionary containing hyperparameter values such as learning
#     rate, momentum, etc. If the update rule requires caching values over many
#     iterations, then config will also hold these cached values.
# Returns:
#   - next_w: The next point after the update.
#   - config: The config dictionary to be passed to the next iteration of the
#     update rule.
# NOTE: For most update rules, the default learning rate will probably not
# perform well; however the default values of the other hyperparameters should
# work well for a variety of different problems.
# For efficiency, update rules may perform in-place updates, mutating w and
# setting next_w equal to w.
# ```
# We provide the implementation of the SGD update rule for your reference in `fully_connected_networks.py`
#
# Now **implement** the SGD+Momentum update rule using the same interface. Run the following to check your implementation of SGD+Momentum. You should see errors less than `1e-7`.

# %%
from fully_connected_networks import sgd_momentum

reset_seed(0)

N, D = 4, 5
w = torch.linspace(-0.4, 0.6, steps=N*D, dtype=torch.float64, device=device).reshape(N, D)
dw = torch.linspace(-0.6, 0.4, steps=N*D, dtype=torch.float64, device=device).reshape(N, D)
v = torch.linspace(0.6, 0.9, steps=N*D, dtype=torch.float64, device=device).reshape(N, D)

config = {'learning_rate': 1e-3, 'velocity': v}
next_w, _ = sgd_momentum(w, dw, config=config)

expected_next_w = torch.tensor([
  [ 0.1406,      0.20738947,  0.27417895,  0.34096842,  0.40775789],
  [ 0.47454737,  0.54133684,  0.60812632,  0.67491579,  0.74170526],
  [ 0.80849474,  0.87528421,  0.94207368,  1.00886316,  1.07565263],
  [ 1.14244211,  1.20923158,  1.27602105,  1.34281053,  1.4096    ]],
   dtype=torch.float64, device=device)
expected_velocity = torch.tensor([
  [ 0.5406,      0.55475789,  0.56891579, 0.58307368,  0.59723158],
  [ 0.61138947,  0.62554737,  0.63970526,  0.65386316,  0.66802105],
  [ 0.68217895,  0.69633684,  0.71049474,  0.72465263,  0.73881053],
  [ 0.75296842,  0.76712632,  0.78128421,  0.79544211,  0.8096    ]],
   dtype=torch.float64, device=device)

# Should see relative errors around e-8 or less
print('next_w error: ', libs.grad.rel_error(next_w, expected_next_w))
print('velocity error: ', libs.grad.rel_error(expected_velocity, config['velocity']))
# Out:
# next_w error:  1.6802078709310813e-09
# velocity error:  2.9254212825785614e-09

# %% [markdown]
# Once you have done so, run the following to train a six-layer network with both SGD and SGD+momentum. You should see the SGD+momentum update rule converge faster.

# %%
from fully_connected_networks import FullyConnectedNet, sgd, sgd_momentum


reset_seed(0)

num_train = 4000
small_data = {
  'X_train': data_dict['X_train'][:num_train],
  'y_train': data_dict['y_train'][:num_train],
  'X_val': data_dict['X_val'],
  'y_val': data_dict['y_val'],
}

solvers = {}

for update_rule_name, update_rule_fn in [('sgd', sgd), ('sgd_momentum', sgd_momentum)]:
  print('running with ', update_rule_name)
  model = FullyConnectedNet([100, 100, 100, 100, 100], weight_scale=5e-2,
                            dtype=torch.float32, device=device)

  solver = Solver(model, small_data,
                  num_epochs=5, batch_size=100,
                  update_rule=update_rule_fn,
                  optim_config={
                    'learning_rate': 5e-2,
                  },
                  print_every=1000,
                  verbose=True,
                  device=device)
  solvers[update_rule_name] = solver
  solver.train()
  print()
  
plt.subplot(3, 1, 1)
plt.title('Training loss')
plt.xlabel('Iteration')
for update_rule, solver in solvers.items():
  plt.plot(solver.loss_history, 'o', label="loss_%s" % update_rule)
plt.legend(loc='lower center', ncol=4)
  
plt.subplot(3, 1, 2)
plt.title('Training accuracy')
plt.xlabel('Epoch')
for update_rule, solver in solvers.items():
  plt.plot(solver.train_acc_history, '-o', label="train_acc_%s" % update_rule)
plt.legend(loc='lower center', ncol=4)

  
plt.subplot(3, 1, 3)
plt.title('Validation accuracy')
plt.xlabel('Epoch')
for update_rule, solver in solvers.items():
  plt.plot(solver.val_acc_history, '-o', label="val_acc_%s" % update_rule)
plt.legend(loc='lower center', ncol=4)

plt.gcf().set_size_inches(10, 20)
plt.show()
# Out:
# running with  sgd
# (Time 2.84 sec; Iteration 1 / 200) loss: 2.302186
# (Epoch 0 / 5) train acc: 0.119000; val_acc: 0.109800
# (Epoch 1 / 5) train acc: 0.098000; val_acc: 0.095300
# (Epoch 2 / 5) train acc: 0.094000; val_acc: 0.095200
# (Epoch 3 / 5) train acc: 0.118000; val_acc: 0.095600
# (Epoch 4 / 5) train acc: 0.108000; val_acc: 0.103400
# (Epoch 5 / 5) train acc: 0.092000; val_acc: 0.095200
#
# running with  sgd_momentum
# (Time 0.00 sec; Iteration 1 / 200) loss: 2.302879
# (Epoch 0 / 5) train acc: 0.099000; val_acc: 0.110800
# (Epoch 1 / 5) train acc: 0.099000; val_acc: 0.099700
# (Epoch 2 / 5) train acc: 0.169000; val_acc: 0.153600
# (Epoch 3 / 5) train acc: 0.164000; val_acc: 0.165700
# (Epoch 4 / 5) train acc: 0.231000; val_acc: 0.206200
# (Epoch 5 / 5) train acc: 0.271000; val_acc: 0.254700

# %% [markdown]
# ## RMSProp
# RMSProp is an update rule that set per-parameter learning rates by using a running average of the second moments of gradients.
#
# **Implement** the RMSProp update rule in the `rmsprop` function in `fully_connected_networks.py`. Run the following to test your RMSProp implementation. You should see errors less than `1e-6`.

# %%
from fully_connected_networks import rmsprop

reset_seed(0)

N, D = 4, 5
w = torch.linspace(-0.4, 0.6, steps=N*D, dtype=torch.float64, device=device).reshape(N, D)
dw = torch.linspace(-0.6, 0.4, steps=N*D, dtype=torch.float64, device=device).reshape(N, D)
cache = torch.linspace(0.6, 0.9, steps=N*D, dtype=torch.float64, device=device).reshape(N, D)

config = {'learning_rate': 1e-2, 'cache': cache}
next_w, _ = rmsprop(w, dw, config=config)

expected_next_w = torch.tensor([
  [-0.39223849, -0.34037513, -0.28849239, -0.23659121, -0.18467247],
  [-0.132737,   -0.08078555, -0.02881884,  0.02316247,  0.07515774],
  [ 0.12716641,  0.17918792,  0.23122175,  0.28326742,  0.33532447],
  [ 0.38739248,  0.43947102,  0.49155973,  0.54365823,  0.59576619]],
   dtype=torch.float64, device=device)
expected_cache = torch.tensor([
  [ 0.5976,      0.6126277,   0.6277108,   0.64284931,  0.65804321],
  [ 0.67329252,  0.68859723,  0.70395734,  0.71937285,  0.73484377],
  [ 0.75037008,  0.7659518,   0.78158892,  0.79728144,  0.81302936],
  [ 0.82883269,  0.84469141,  0.86060554,  0.87657507,  0.8926    ]],
   dtype=torch.float64, device=device)

print('next_w error: ', libs.grad.rel_error(expected_next_w, next_w))
print('cache error: ', libs.grad.rel_error(expected_cache, config['cache']))
# Out:
# next_w error:  4.064797880829826e-09
# cache error:  1.8620321382570356e-09

# %% [markdown]
# ## Adam
# Adam extends RMSprop with a first-order gradient cache similar to momentum, and a bias correction mechanism to prevent large steps at the start of optimization. Adam is one of the most commonly used update rules used in practice for training deep neural networks.
#
# Implement the Adam update rule in the `adam` function in `fully_connected_networks.py`. Run the following to test your Adam implementation. You should see error less than `1e-6` for `next_w`, and errors less than `1e-8` for `v` and `m`:
#
#
#
# **NOTE:** Please implement the _complete_ Adam update rule (with the bias correction mechanism).

# %%
from fully_connected_networks import adam

reset_seed(0)

N, D = 4, 5
w = torch.linspace(-0.4, 0.6, steps=N*D, dtype=torch.float64, device=device).reshape(N, D)
dw = torch.linspace(-0.6, 0.4, steps=N*D, dtype=torch.float64, device=device).reshape(N, D)
m = torch.linspace(0.6, 0.9, steps=N*D, dtype=torch.float64, device=device).reshape(N, D)
v = torch.linspace(0.7, 0.5, steps=N*D, dtype=torch.float64, device=device).reshape(N, D)

config = {'learning_rate': 1e-2, 'm': m, 'v': v, 't': 5}
next_w, _ = adam(w, dw, config=config)

expected_next_w = torch.tensor([
  [-0.40094747, -0.34836187, -0.29577703, -0.24319299, -0.19060977],
  [-0.1380274,  -0.08544591, -0.03286534,  0.01971428,  0.0722929],
  [ 0.1248705,   0.17744702,  0.23002243,  0.28259667,  0.33516969],
  [ 0.38774145,  0.44031188,  0.49288093,  0.54544852,  0.59801459]],
   dtype=torch.float64, device=device)
expected_v = torch.tensor([
  [ 0.69966,     0.68908382,  0.67851319,  0.66794809,  0.65738853,],
  [ 0.64683452,  0.63628604,  0.6257431,   0.61520571,  0.60467385,],
  [ 0.59414753,  0.58362676,  0.57311152,  0.56260183,  0.55209767,],
  [ 0.54159906,  0.53110598,  0.52061845,  0.51013645,  0.49966,   ]],
   dtype=torch.float64, device=device)
expected_m = torch.tensor([
  [ 0.48,        0.49947368,  0.51894737,  0.53842105,  0.55789474],
  [ 0.57736842,  0.59684211,  0.61631579,  0.63578947,  0.65526316],
  [ 0.67473684,  0.69421053,  0.71368421,  0.73315789,  0.75263158],
  [ 0.77210526,  0.79157895,  0.81105263,  0.83052632,  0.85      ]],
   dtype=torch.float64, device=device)

# You should see relative errors around e-7 or less
print('next_w error: ', libs.grad.rel_error(expected_next_w, next_w))
print('v error: ', libs.grad.rel_error(expected_v, config['v']))
print('m error: ', libs.grad.rel_error(expected_m, config['m']))
# Out:
# next_w error:  3.756728297598868e-09
# v error:  3.4048987160545265e-09
# m error:  2.786377729853651e-09

# %% [markdown]
# Once you have debugged your RMSProp and Adam implementations, run the following to train a pair of deep networks using these new update rules:

# %%
from fully_connected_networks import adam, rmsprop, FullyConnectedNet

for update_rule_name, update_rule_fn, learning_rate in [('adam', adam, 1e-3), ('rmsprop', rmsprop, 1e-4)]:
  print('running with ', update_rule)
  model = FullyConnectedNet([100, 100, 100, 100, 100], weight_scale=5e-2, device=device)

  solver = Solver(model, small_data,
                  num_epochs=5, batch_size=100,
                  update_rule=update_rule_fn,
                  optim_config={
                    'learning_rate': learning_rate
                  },
                  print_every=1000,
                  verbose=True, device=device)
  solvers[update_rule_name] = solver
  solver.train()
  print()

plt.subplot(3, 1, 1)
plt.title('Training loss')
plt.xlabel('Iteration')
for update_rule, solver in list(solvers.items()):
  plt.plot(solver.loss_history, 'o', label=update_rule)
plt.legend(loc='lower center', ncol=4)
  
plt.subplot(3, 1, 2)
plt.title('Training accuracy')
plt.xlabel('Epoch')
for update_rule, solver in list(solvers.items()):
  plt.plot(solver.train_acc_history, '-o', label=update_rule)
plt.legend(loc='lower center', ncol=4)

plt.subplot(3, 1, 3)
plt.title('Validation accuracy')
plt.xlabel('Epoch')
for update_rule, solver in list(solvers.items()):
  plt.plot(solver.val_acc_history, '-o', label=update_rule)
plt.legend(loc='lower center', ncol=4)

plt.gcf().set_size_inches(10, 20)
plt.show()
# Out:
# running with  sgd_momentum
# (Time 0.01 sec; Iteration 1 / 200) loss: 2.302186
# (Epoch 0 / 5) train acc: 0.134000; val_acc: 0.116800
# (Epoch 1 / 5) train acc: 0.285000; val_acc: 0.254100
# (Epoch 2 / 5) train acc: 0.300000; val_acc: 0.284100
# (Epoch 3 / 5) train acc: 0.344000; val_acc: 0.297200
# (Epoch 4 / 5) train acc: 0.387000; val_acc: 0.321400
# (Epoch 5 / 5) train acc: 0.431000; val_acc: 0.354500
#
# running with  sgd_momentum
# (Time 0.01 sec; Iteration 1 / 200) loss: 2.302879
# (Epoch 0 / 5) train acc: 0.150000; val_acc: 0.148200
# (Epoch 1 / 5) train acc: 0.213000; val_acc: 0.199900
# (Epoch 2 / 5) train acc: 0.244000; val_acc: 0.239400
# (Epoch 3 / 5) train acc: 0.264000; val_acc: 0.256600
# (Epoch 4 / 5) train acc: 0.299000; val_acc: 0.277400
# (Epoch 5 / 5) train acc: 0.295000; val_acc: 0.279500

# %% [markdown]
# # Dropout (Bonus)
# Dropout [1] is a technique for regularizing neural networks by randomly setting some output activations to zero during the forward pass. In this exercise you will implement a dropout layer and modify your fully-connected network to optionally use dropout.
#
# [1] [Geoffrey E. Hinton et al, "Improving neural networks by preventing co-adaptation of feature detectors", arXiv 2012](https://arxiv.org/abs/1207.0580)

# %% [markdown]
# ## Dropout: forward
# **Implement** the forward pass for dropout in `fully_connected_networks.py`. Since dropout behaves differently during training and testing, make sure to implement the operation for both modes.
#
# Run the following to test your dropout implementation. The mean of the output should be approximately the same during training and testing. During training the number of outputs set to zero should be approximately equal to the drop probability `p`, and during testing no outputs should be set to zero.

# %%
from fully_connected_networks import Dropout

reset_seed(0)
x = torch.randn(500, 500, dtype=torch.float64, device=device) + 10

for p in [0.25, 0.4, 0.7]:
  out, _ = Dropout.forward(x, {'mode': 'train', 'p': p})
  out_test, _ = Dropout.forward(x, {'mode': 'test', 'p': p})

  print('Running tests with p = ', p)
  print('Mean of input: ', x.mean().item())
  print('Mean of train-time output: ', out.mean().item())
  print('Mean of test-time output: ', out_test.mean().item())
  print('Fraction of train-time output set to zero: ', (out == 0).type(torch.float32).mean().item())
  print('Fraction of test-time output set to zero: ', (out_test == 0).type(torch.float32).mean().item())
  print()
# Out:
# Running tests with p =  0.25
# Mean of input:  9.996859266056045
# Mean of train-time output:  9.9919537724218
# Mean of test-time output:  9.996859266056045
# Fraction of train-time output set to zero:  0.25043198466300964
# Fraction of test-time output set to zero:  0.0
#
# Running tests with p =  0.4
# Mean of input:  9.996859266056045
# Mean of train-time output:  9.98152255861487
# Mean of test-time output:  9.996859266056045
# Fraction of train-time output set to zero:  0.4009760022163391
# Fraction of test-time output set to zero:  0.0
#
# Running tests with p =  0.7
# Mean of input:  9.996859266056045
# Mean of train-time output:  10.024262342380375
# Mean of test-time output:  9.996859266056045
# Fraction of train-time output set to zero:  0.6991959810256958
# Fraction of test-time output set to zero:  0.0

# %% [markdown]
# ## Dropout: backward
# Implement the backward pass for dropout. After doing so, run the following cell to numerically gradient-check your implementation.

# %%
from fully_connected_networks import Dropout

reset_seed(0)
x = torch.randn(10, 10, dtype=torch.float64, device=device) + 10
dout = torch.randn_like(x)

dropout_param = {'mode': 'train', 'p': 0.2, 'seed': 0}
out, cache = Dropout.forward(x, dropout_param)
dx = Dropout.backward(dout, cache)
dx_num = libs.grad.compute_numeric_gradient(lambda xx: Dropout.forward(xx, dropout_param)[0], x, dout)

# Error should be around e-10 or less
print('dx relative error: ', libs.grad.rel_error(dx, dx_num))
# Out:
# dx relative error:  3.882378970269327e-09

# %% [markdown]
# # Fully-connected nets with dropout (Bonus)
# Modify your implementation of `FullyConnectedNet` to use dropout. Specifically, if the constructor of the network receives a value that is not 0 for the `dropout` parameter, then the net should add a dropout layer immediately after every ReLU nonlinearity.
#
# After doing so, run the following to numerically gradient-check your implementation. You should see errors less than `1e-5`, and different dropout rates should result different error values.

# %%
from fully_connected_networks import FullyConnectedNet

reset_seed(0)

N, D, H1, H2, C = 2, 15, 20, 30, 10
X = torch.randn(N, D, dtype=torch.float64, device=device)
y = torch.randint(C, size=(N,), dtype=torch.int64, device=device)

for dropout in [0, 0.25, 0.5]:
  print('Running check with dropout = ', dropout)
  model = FullyConnectedNet([H1, H2], input_dim=D, num_classes=C,
                            weight_scale=5e-2, dropout=dropout,
                            seed=0, dtype=torch.float64, device=device)

  loss, grads = model.loss(X, y)
  print('Initial loss: ', loss.item())
  
  # Relative errors should be around e-5 or less.
  for name in sorted(grads):
    f = lambda _: model.loss(X, y)[0]
    grad_num = libs.grad.compute_numeric_gradient(f, model.params[name])
    print('%s relative error: %.2e' % (name, libs.grad.rel_error(grad_num, grads[name])))
  print()
# Out:
# Running check with dropout =  0
# Initial loss:  2.3053575717037686
# W1 relative error: 5.28e-08
# W2 relative error: 8.33e-08
# W3 relative error: 4.64e-08
# b1 relative error: 1.28e-07
# b2 relative error: 1.83e-08
# b3 relative error: 2.57e-09
#
# Running check with dropout =  0.25
# Initial loss:  2.313601286227244
# W1 relative error: 2.88e-08
# W2 relative error: 3.57e-08
# W3 relative error: 1.89e-08
# b1 relative error: 5.80e-08
# b2 relative error: 1.27e-08
# b3 relative error: 3.12e-09
#
# Running check with dropout =  0.5
# Initial loss:  2.312331406530074
# W1 relative error: 1.28e-08
# W2 relative error: 9.54e-09
# W3 relative error: 8.47e-09
# b1 relative error: 3.04e-08
# b2 relative error: 9.89e-09
# b3 relative error: 3.21e-09

# %% [markdown]
# ## Regularization experiment
# To get a sense of the way that dropout can regularize a neural network, we will train three different two-layer networks:
#
# 1. Hidden size 256, dropout = 0
# 2. Hidden size 512, dropout = 0
# 3. Hidden size 512, dropout = 0.5
#
# We will then visualize the training and validation accuracies of these three networks.

# %%
from fully_connected_networks import FullyConnectedNet

# Train two identical nets, one with dropout and one without
reset_seed(0)
num_train = 20000
small_data = {
  'X_train': data_dict['X_train'][:num_train],
  'y_train': data_dict['y_train'][:num_train],
  'X_val': data_dict['X_val'],
  'y_val': data_dict['y_val'],
}

solvers = {}
dropout_choices = [0, 0, 0.5]
width_choices = [256, 512, 512]
for dropout, width in zip(dropout_choices, width_choices):
# for dropout in dropout_choices:
  model = FullyConnectedNet([width], dropout=dropout, dtype=torch.float32, device=device)
  print('Training a model with dropout=%.2f and width=%d' % (dropout, width))

  solver = Solver(model, small_data,
                  num_epochs=100, batch_size=512,
                  update_rule=adam,
                  optim_config={
                    'learning_rate': 5e-3,
                  },
                  print_every=100000, print_acc_every=10,
                  verbose=True, device=device)
  solver.train()
  solvers[(dropout, width)] = solver
  print()
# Out:
# Training a model with dropout=0.00 and width=256
# (Time 0.01 sec; Iteration 1 / 3900) loss: 2.302899
# (Epoch 0 / 100) train acc: 0.211000; val_acc: 0.193800
# (Epoch 10 / 100) train acc: 0.698000; val_acc: 0.472200
# (Epoch 20 / 100) train acc: 0.860000; val_acc: 0.466800
# (Epoch 30 / 100) train acc: 0.949000; val_acc: 0.473100
# (Epoch 40 / 100) train acc: 0.949000; val_acc: 0.471100
# (Epoch 50 / 100) train acc: 0.950000; val_acc: 0.457000
# (Epoch 60 / 100) train acc: 0.982000; val_acc: 0.474100
# (Epoch 70 / 100) train acc: 0.949000; val_acc: 0.459700
# (Epoch 80 / 100) train acc: 0.979000; val_acc: 0.473100
# (Epoch 90 / 100) train acc: 1.000000; val_acc: 0.475800
# (Epoch 100 / 100) train acc: 1.000000; val_acc: 0.480700
#
# Training a model with dropout=0.00 and width=512
# (Time 0.00 sec; Iteration 1 / 3900) loss: 2.298170
# (Epoch 0 / 100) train acc: 0.228000; val_acc: 0.228200
# (Epoch 10 / 100) train acc: 0.745000; val_acc: 0.471200
# (Epoch 20 / 100) train acc: 0.889000; val_acc: 0.478300
# (Epoch 30 / 100) train acc: 0.895000; val_acc: 0.468100
# (Epoch 40 / 100) train acc: 0.930000; val_acc: 0.468100
# (Epoch 50 / 100) train acc: 0.981000; val_acc: 0.485500
# (Epoch 60 / 100) train acc: 0.915000; val_acc: 0.468900
# (Epoch 70 / 100) train acc: 0.967000; val_acc: 0.468500
# (Epoch 80 / 100) train acc: 0.962000; val_acc: 0.470300
# (Epoch 90 / 100) train acc: 0.945000; val_acc: 0.464800
# (Epoch 100 / 100) train acc: 0.975000; val_acc: 0.472600
#
# Training a model with dropout=0.50 and width=512
# (Time 0.00 sec; Iteration 1 / 3900) loss: 2.303071
# (Epoch 0 / 100) train acc: 0.220000; val_acc: 0.206000
# (Epoch 10 / 100) train acc: 0.561000; val_acc: 0.459500
# (Epoch 20 / 100) train acc: 0.670000; val_acc: 0.486400
# (Epoch 30 / 100) train acc: 0.772000; val_acc: 0.483000
# (Epoch 40 / 100) train acc: 0.820000; val_acc: 0.496900
# (Epoch 50 / 100) train acc: 0.844000; val_acc: 0.503900
# (Epoch 60 / 100) train acc: 0.887000; val_acc: 0.498900
# (Epoch 70 / 100) train acc: 0.866000; val_acc: 0.490500
# (Epoch 80 / 100) train acc: 0.917000; val_acc: 0.503400
# (Epoch 90 / 100) train acc: 0.940000; val_acc: 0.493800
# (Epoch 100 / 100) train acc: 0.947000; val_acc: 0.489700

# %% [markdown]
# If everything worked as expected, you should see that the network with dropout has lower training accuracies than the networks without dropout, but that it achieves higher validation accuracies.
#
# You should also see that a network with width 512 and dropout 0.5 achieves higher validation accuracies than a network with width 256 and no dropout. This demonstrates that reducing the model size is not generally an effective regularization strategy -- it's often better to use a larger model with explicit regularization.

# %%
plt.subplot(2, 1, 1)
for (dropout, width), solver in solvers.items():
  train_acc = solver.train_acc_history
  label = 'dropout=%.2f, width=%d' % (dropout, width)
  plt.plot(train_acc, 'o', label=label)
plt.title('Train accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(ncol=2, loc='lower right')
  
plt.subplot(2, 1, 2)
for (dropout, width), solver in solvers.items():
  val_acc = solver.val_acc_history
  label = 'dropout=%.2f, width=%d' % (dropout, width)
  plt.plot(val_acc, 'o', label=label)
plt.ylim(0.4, 0.52)
plt.title('Val accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(ncol=2, loc='lower right')

plt.gcf().set_size_inches(10, 15)
plt.show()
